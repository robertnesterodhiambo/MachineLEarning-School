# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\neste\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\neste\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# Creating a dummy dataset
np.random.seed(42)
data = {
    'Category': np.random.choice(['A', 'B', 'C', 'D'], size=100),
    'Value1': np.random.normal(0, 1, 100),
    'Value2': np.random.normal(10, 2, 100),
    'Day': np.random.choice(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], size=100),
    'Gender': np.random.choice(['Male', 'Female'], size=100)
}

df = pd.DataFrame(data)
df
# Out:
#    Category    Value1     Value2        Day  Gender
# 0         C  0.738467  10.454920   Thursday  Female
# 1         D  0.171368  12.614286    Tuesday  Female
# 2         A -0.115648   6.785034    Tuesday    Male
# 3         C -0.301104  10.369268     Friday    Male
# 4         C -1.478522  10.519766    Tuesday    Male
# ..      ...       ...        ...        ...     ...
# 95        B  1.549934  11.267838     Friday  Female
# 96        B -0.783253   5.949715    Tuesday  Female
# 97        D -0.322062  10.372909     Friday  Female
# 98        B  0.813517   8.676427  Wednesday    Male
# 99        A -1.230864  11.704867     Friday    Male
#
# [100 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.set() # set default themea

# %%
#scatter plots
sns.scatterplot(x = 'Value1', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Value2'>

# %%
#lienplot
sns.lineplot(x = 'Value1', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Value2'>

# %%
#BARPLOT
sns.barplot(x = 'Category', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Value2'>

# %%
#Boxplot
sns.boxplot(x = 'Category', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Value2'>

# %%
#distribution plot
sns.histplot(x = 'Value1', data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Count'>

# %%
#kernel ldenisty plot
sns.kdeplot(x = 'Value1',  data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Density'>

# %%
#kde with 2 sides
sns.kdeplot(x = 'Value1', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Value2'>

# %%
#kde with 2 sides
#kernel ldenisty plot
sns.kdeplot(x = 'Value1',  data = df)

sns.kdeplot(x = 'Value1', y = 'Value2', data = df)
# Out:
# <Axes: xlabel='Value1', ylabel='Density'>

# %%
#pair plots
sns.pairplot(df[['Value1', 'Value2','Category']], hue = 'Category')

# %%
#%%
#heatmaps
corelation_matrix = df[['Value1', 'Value2']].corr()
sns.heatmap(corelation_matrix, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
#wee have been using default theme now we will use  pernsonlized theme
sns.set_palette('husl')
sns.set_style('whitegrid')

# %%
#setting title and labels
#for plt to work import matplotlib as plt
import matplotlib.pyplot as plt
#note thsi will result in errors as we dont have a plot with function plt
plt.title('Tittle')
plt.xlabel('X-alebl')
plt.ylabel('y-alebl')
# Out:
# Text(0, 0.5, 'y-alebl')

# %%
#avanced grids
g = sns.FacetGrid(df, col = 'Day', hue = 'Gender')
#lets fix this by adding more features
g.map(plt.scatter, 'Value1', 'Value2', alpha = 0.7)
g.add_legend()

# %%
#regression line tih hue
sns.lmplot(x = 'Value1', y = 'Value2', data = df, hue = 'Gender')

# %%
g = sns.PairGrid(df, hue = 'Category')
g.map_diag(plt.hist)
g.add_legend()

# %%
#custome pa;ettes
custom_palette = sns.color_palette("husl",4)
sns.boxplot(x = 'Category', y = 'Value1', data = df, palette = custom_palette)
# Out:
# C:\Users\neste\AppData\Local\Temp\ipykernel_11316\3045381957.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Category', y = 'Value1', data = df, palette = custom_palette)
# <Axes: xlabel='Category', ylabel='Value1'>
