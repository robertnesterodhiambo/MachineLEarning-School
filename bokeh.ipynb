# %%
pip install bokeh
#this installs bokeh package and takes a while
# Out:
# Requirement already satisfied: bokeh in c:\users\neste\appdata\local\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (23.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\neste\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.io import output_notebook

# %%
x = [12, 56, 89, 32, 54]
y = [95, 26, 24, 28, 51]
#creates a dummy df

# %%
output_notebook()
plot = figure(title = "Scatter plot", x_axis_label = "X-axis", y_axis_label = "Y-Axis")
plot.circle(x, y, size = 10, color = "blue")
show(plot)
#this plots in anew page
#create a figure s first
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c2e8a193-cd15-4459-a5a5-91ef76b02287">Loading BokehJS ...</span>
#     </div>
#   <div id="abc2ea06-793f-4644-aa08-5944b9a53f88" data-root-id="p1040" style="display: contents;"></div>

# %%
output_notebook()
# creating a line plot
plot = figure(title = "line plot", x_axis_label = "X-axis", y_axis_label = "Y-Axis")
plot.line(x, y, line_width = 2, line_color = "purple", legend_label = 'Line')
show(plot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f72ede4c-6818-4fe5-a365-c0e407fc3ed2">Loading BokehJS ...</span>
#     </div>
#   <div id="e6cbc483-b83f-4afc-afa6-487a2796520b" data-root-id="p1078" style="display: contents;"></div>

# %%
output_notebook()
# box plot
#we will create a new df
fruits  = ["A", "B", "C", "D"]
counts = [23, 26, 89,  52]
plot = figure(x_range =  fruits, title = "bar plot", x_axis_label = "Fruits", y_axis_label = "Countrs")
plot.vbar(x = fruits, top = counts, width = 0.5, color = "orange")
show(plot)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c3f3fae5-98e5-4005-a48a-cf776fe11819">Loading BokehJS ...</span>
#     </div>
#   <div id="d21c5b37-15a9-45dd-91b6-8e2f9cbd7926" data-root-id="p1118" style="display: contents;"></div>

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ba6c5234-0ef0-481e-89c2-be42f7ce2302">Loading BokehJS ...</span>
#     </div>

# %%
#interactive widgets
from bokeh.layouts import column
from bokeh.models import Slider

# %%
output_notebook()
# Create a figure
plot = figure(title='Interactive Plot with Slider', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add a scatter plot
source = ColumnDataSource(data=dict(x=x, y=y))
plot.circle('x', 'y', source=source, size=10, color='blue')

# Add a slider
slider = Slider(start=1, end=80, value=1, step=1, title='Scale Factor')

# Update plot based on slider value
def update(attr, old, new):
    source.data = dict(x=x, y=[i * slider.value for i in y])
    slider.on_change('value', update)

# Show the plot with the slider
layout = column(slider, plot)
show(layout)
#advance bokeh uses javascript concept toreder the slider functions
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f34ae32b-e1bb-41c8-ade4-a0ed73cfaf3e">Loading BokehJS ...</span>
#     </div>
#   <div id="b6f90c9b-5eaf-4252-9a45-d0cd4a334f71" data-root-id="p1242" style="display: contents;"></div>

# %%
output_notebook()
#gridplots
#to get the gridplot
from bokeh.layouts import gridplot
x = [12, 56, 89, 32, 54]
y = [95, 26, 24, 28, 51]
y1 = [56, 89, 23, 19, 37]
plot1 = figure(title = "plot 1", x_axis_label = "X-axis", y_axis_label = "Y-Axis")
plot2 = figure(title = "plot2 ", x_axis_label = "X-axis", y_axis_label = "Y-Axis")
plot1.line(x, y, line_width = 2, line_color = "blue")
plot2.line(x, y1, line_width = 2, line_color = "green")
#layout of two plots
layout = gridplot([[plot1,plot2]])
show(layout)
#creates a dummy df
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ff5331da-63f1-492d-966c-292dc6332274">Loading BokehJS ...</span>
#     </div>
#   <div id="a9aedc6a-6504-4366-95b0-25bb283f78fa" data-root-id="p1326" style="display: contents;"></div>
