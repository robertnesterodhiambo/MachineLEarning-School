# %% [markdown]
# # GETTING THE DATA READY
# I have used excel to manipulate the data into a valuable set theta i would use. Using the FactInternetSales datasets I broke it down into a suitable sustainable form.
#
# ###  CustomerKey
# The customer key gives us a leeway into the DimCustomer table. from here we get 29 columns but not all will be of interest for this aanlysis. we used the VLOOKUP function in excel to get the exact geography key for every custommer based on the customerkey. The CustomerAlternateKey	Title	FirstName	MiddleName	LastName	NameStyle columns re not that necesary for this analysis incomparison to the content they store. we have an interest in sales  and everything feasible about the sales and customers. The birthdate will be important in geting the customers age rane and understand the buying patterns of different agegroups. Gender is also important in understanding what goods are common among diferent genders. Email adress are not necesary for analysis. YearlyIncome	TotalChildren	NumberChildrenAtHome are all important to understand customers buying the specific goods and know how the number of children will affect the buuying patterns and what they will buy.EnglishEducation will help us understanding the buying behavour based on the level of education. HouseOwnerFlag	NumberCarsOwned CommuteDistance are also eseantial in this analysis as they will prob further understandingt he buying pattersn based on cars owned and if the disytance has a significant affect on buying behavior. from the DimCustomer table we  will only pick thee mentioned tables.
#
# ###  ProductKey
# the Product key gives as an insight into the dimProduct data. from this data we only get the actual products name so that we can have an exact product names instead of product keys. in this we also use the VLOOKUP function to get the ecact key along with its name onto the FactinternetSales data.
#
# ### DimProductSubcategoryKey
# This gives us the leeway to  DimProductSubcategory dataset where we get the subcategory names of each datasset into our datset.
#
# ###   DimSalesTerritoryKey
#
# DimSalesTerritoryKey allows for the matching of data in the DimSalesTerritory data and get the Teritory names for each teritory location.
#
# ###     geography key
# this key points us to DimGeography where we  get cityy country and locations in general of the customers.
#
# ###   CurrencyKey
#
# DimCurrency is directe related to this key where we get curency name used instead of  having the curency keys.
#
#      -  **these are the datasets chosen with their respective columns. these tables are merged into the FactinternetSales data table**
#
# ###   SalesTerritoryKey
# this column helps in getting the sales by teritory for the sakes agenst and also get the targets set fro them in the  FactSalesTargets dataset.
#
# ###   DimPromotionKey
#  this column leads us to the DimPromotion  table where we get promotion names into the main data
# ###   TABLES NOT CHOSEM
#     - DimAccount helps in understanding the account types for customers which is not a point of interest in this analysis.
#     - DimDate is dates stored with weekid and names of the weeks which can still be imported from python without the need of the table being added into the dataset. the date keys are also not complte
#     - DimDepartmentGroup  is the departmental grouping of thedepartments in the  DimOrganization ddata.
#     - DimReseller DimSalesReason DimScenario FactCallCenter FactCurrencyRate FactFinance

# %% [markdown]
# # data importaion into the environment

# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Define the path to your CSV file
csv_path = "C:/Users/neste/OneDrive/Desktop/karanja/DataSet_final/DataSet_final/ty/FactInternetSales.csv"

# Read the CSV file into a DataFrame and name it 'sales'
sales = spark.read.csv(csv_path, header=True, inferSchema=True)

# Show the first few rows of the DataFrame
sales.show()
# Out:
# +-----------+---------------+-------------------+---------------+----------+---------------------+-----------------------------+--------------------+------------+----------+-----------+--------------+-------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+------------+-----------+-----------+--------------------+-----------------+---------------------+----------------+----------------+--------------------+--------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------------------+----------------+---------+-------+--------+
# |CustomerKey|CommuteDistance|   EnglishEducation|marital statust|ProductKey|ProductSubcategoryKey|EnglishProductSubcategoryName|  EnglishProductName|OrderDateKey|DueDateKey|ShipDateKey|Sales Terirory|geography key|       Country|         CITY|           Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income| birthdate|Gender|PromotionKey| promo name|CurrencyKey|        CurrencyName|SalesTerritoryKey|SalesTerritoryCountry|SalesAmountQuote|SalesOrderNumber|SalesOrderLineNumber|RevisionNumber|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|CarrierTrackingNumber|CustomerPONumber|OrderDate|DueDate|ShipDate|
# +-----------+---------------+-------------------+---------------+----------+---------------------+-----------------------------+--------------------+------------+----------+-----------+--------------+-------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+------------+-----------+-----------+--------------------+-----------------+---------------------+----------------+----------------+--------------------+--------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------------------+----------------+---------+-------+--------+
# |      21768|      10+ Miles|          Bachelors|              S|       310|                    2|                   Road Bikes|    Road-150 Red, 62|    20101229|  20110110|   20110105|     Southwest|           53|        Canada|    Metchosin|   British Columbia|              3|             1|                  0|             5|      70000.0| 8/22/1946|     M|           1|No Discount|         19|     Canadian Dollar|                6|               Canada|       1892000.0|         SO43697|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      28389|      0-1 Miles|        High School|              S|       346|                    1|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest|          222|        France|       Pantin|  Seine Saint Denis|              0|             0|                  3|             3|      20000.0|12/18/1964|     F|           1|No Discount|         39|        French Franc|                7|               France|       1002000.0|         SO43698|                   1|             1|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      25863|      10+ Miles|        High School|              S|       346|                    1|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest|          543| United States|      Lebanon|             Oregon|              3|             1|                  0|             5|      40000.0| 12/3/1946|     F|           1|No Discount|        100|           US Dollar|                1|        United States|       2693000.0|         SO43699|                   1|             1|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      14501|      1-2 Miles|    Graduate Degree|              M|       336|                    2|                   Road Bikes|  Road-650 Black, 62|    20101229|  20110110|   20110105|     Southwest|          300| United States|Beverly Hills|         California|              2|             1|                  0|             4|      80000.0| 5/13/1938|     M|           1|No Discount|        100|           US Dollar|                4|        United States|       2427000.0|         SO43700|                   1|             1|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      11003|     5-10 Miles|          Bachelors|              S|       346|                    1|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest|           11|     Australia|   North Ryde|    New South Wales|              1|             0|                  0|             0|      70000.0| 2/15/1968|     F|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43701|                   1|             1|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      27645|     5-10 Miles|        High School|              M|       311|                    2|                   Road Bikes|    Road-150 Red, 44|    20101230|  20110111|   20110106|     Southwest|          312| United States|     Coronado|         California|              4|             1|                  3|             1|     120000.0| 8/18/1961|     M|           1|No Discount|        100|           US Dollar|                4|        United States|       2427000.0|         SO43702|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      16624|      10+ Miles|          Bachelors|              S|       310|                    2|                   Road Bikes|    Road-150 Red, 62|    20101230|  20110111|   20110106|     Southwest|           30|     Australia|        Perth|    South Australia|              3|             0|                  0|             0|      90000.0| 7/27/1972|     M|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43703|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      11005|     5-10 Miles|          Bachelors|              S|       351|                    1|               Mountain Bikes|Mountain-100 Blac...|    20101230|  20110111|   20110106|     Southwest|           22|     Australia|East Brisbane|         Queensland|              1|             1|                  0|             0|      70000.0|  8/5/1965|     M|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43704|                   1|             1|            1|  3374.99|       3374.99|                 0.0|           0.0|            1898.09|         1898.09|    3374.99| 270.0|  84.37|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      11011|      10+ Miles|          Bachelors|              M|       344|                    1|               Mountain Bikes|Mountain-100 Silv...|    20101230|  20110111|   20110106|     Southwest|           22|     Australia|East Brisbane|         Queensland|              4|             1|                  4|             4|      60000.0| 11/4/1963|     M|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43705|                   1|             1|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      27621|      1-2 Miles|    Graduate Degree|              S|       312|                    2|                   Road Bikes|    Road-150 Red, 48|    20101231|  20110112|   20110107|     Southwest|          369| United States| Santa Monica|         California|              4|             0|                  0|             0|     160000.0| 1/27/1964|     M|           1|No Discount|        100|           US Dollar|                4|        United States|       2427000.0|         SO43706|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      27616|      2-5 Miles|          Bachelors|              S|       312|                    2|                   Road Bikes|    Road-150 Red, 48|    20101231|  20110112|   20110107|     Southwest|          335| United States|  Lemon Grove|         California|              4|             1|                  2|             3|     120000.0|12/11/1965|     F|           1|No Discount|        100|           US Dollar|                4|        United States|       2427000.0|         SO43707|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      20042|      1-2 Miles|          Bachelors|              M|       330|                    2|                   Road Bikes|    Road-650 Red, 52|    20101231|  20110112|   20110107|     Southwest|          268|United Kingdom|    Liverpool|            England|              0|             1|                  1|             1|      40000.0|  5/4/1974|     M|           1|No Discount|         98|United Kingdom Pound|               10|       United Kingdom|       2212000.0|         SO43708|                   1|             1|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      16351|      1-2 Miles|    Partial College|              S|       313|                    2|                   Road Bikes|    Road-150 Red, 52|    20101231|  20110112|   20110107|     Southwest|           26|     Australia|  Rockhampton|         Queensland|              2|             0|                  0|             2|      80000.0|  7/7/1954|     F|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43709|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      16517|      2-5 Miles|        High School|              M|       314|                    2|                   Road Bikes|    Road-150 Red, 56|    20101231|  20110112|   20110107|     Southwest|           19|     Australia|   Wollongong|    New South Wales|              0|             1|                  1|             1|      10000.0| 3/19/1976|     F|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43710|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      27606|      0-1 Miles|    Partial College|              S|       314|                    2|                   Road Bikes|    Road-150 Red, 56|    20110101|  20110113|   20110108|     Southwest|          545| United States|    Milwaukie|             Oregon|              0|             0|                  1|             2|      70000.0| 5/27/1957|     F|           1|No Discount|        100|           US Dollar|                1|        United States|       2693000.0|         SO43711|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      13513|      0-1 Miles|          Bachelors|              M|       311|                    2|                   Road Bikes|    Road-150 Red, 44|    20110101|  20110113|   20110108|     Southwest|          162|       Germany|        Werne|Nordrhein-Westfalen|              0|             1|                  0|             1|      30000.0|  9/8/1941|     F|           1|No Discount|         29|       Deutsche Mark|                8|              Germany|        993000.0|         SO43712|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      27601|      2-5 Miles|Partial High School|              S|       310|                    2|                   Road Bikes|    Road-150 Red, 62|    20110102|  20110114|   20110109|     Southwest|          301| United States|      Burbank|         California|              3|             0|                  1|             3|      60000.0|11/10/1953|     F|           1|No Discount|        100|           US Dollar|                4|        United States|       2427000.0|         SO43713|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      13591|      0-1 Miles|          Bachelors|              M|       311|                    2|                   Road Bikes|    Road-150 Red, 44|    20110102|  20110114|   20110109|     Southwest|          278|United Kingdom|         York|            England|              3|             1|                  5|             0|     170000.0| 5/25/1953|     F|           1|No Discount|         98|United Kingdom Pound|               10|       United Kingdom|       2212000.0|         SO43714|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      16483|     5-10 Miles|          Bachelors|              M|       314|                    2|                   Road Bikes|    Road-150 Red, 56|    20110102|  20110114|   20110109|     Southwest|           35|     Australia|    Melbourne|           Victoria|              2|             1|                  0|             2|      40000.0|10/17/1950|     M|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43715|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# |      16529|      0-1 Miles|          Bachelors|              M|       311|                    2|                   Road Bikes|    Road-150 Red, 44|    20110102|  20110114|   20110109|     Southwest|            4|     Australia|     Goulburn|    New South Wales|              0|             1|                  0|             0|      20000.0| 7/28/1977|     M|           1|No Discount|          6|   Australian Dollar|                9|            Australia|        867000.0|         SO43716|                   1|             1|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|                 NULL|            NULL|  00:00.0|00:00.0| 00:00.0|
# +-----------+---------------+-------------------+---------------+----------+---------------------+-----------------------------+--------------------+------------+----------+-----------+--------------+-------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+------------+-----------+-----------+--------------------+-----------------+---------------------+----------------+----------------+--------------------+--------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------------------+----------------+---------+-------+--------+
# only showing top 20 rows

# %% [markdown]
# ProductKey ProductSubcategoryKey OrderDateKey DueDateKey	ShipDateKey	 geography key PromotionKey CurrencyKey SalesTerritoryKey SalesOrderNumber SalesOrderLineNumber	RevisionNumber CarrierTrackingNumber	CustomerPONumber these columns are to be omited from my data as they dont refrence to any esential data but they are keys and irelvant information for analysis as hey dont have any singifacne in analysis.

# %%
# Columns to omit
columns_to_omit = [
    "ProductKey",
    "ProductSubcategoryKey",
    "geography key",
    "PromotionKey",
    "CurrencyKey",
    "SalesTerritoryKey",
    "SalesOrderNumber",
    "SalesOrderLineNumber",
    "RevisionNumber",
    "CarrierTrackingNumber",
    "CustomerPONumber"
]

# Drop the specified columns
sales_filtered = sales.drop(*columns_to_omit)

# Show the DataFrame
sales_filtered.show()

sales_filtered.columns
# Out:
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+
# |CustomerKey|CommuteDistance|   EnglishEducation|marital statust|EnglishProductSubcategoryName|  EnglishProductName|OrderDateKey|DueDateKey|ShipDateKey|Sales Terirory|       Country|         CITY|           Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income| birthdate|Gender| promo name|        CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderDate|DueDate|ShipDate|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+
# |      21768|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|    20101229|  20110110|   20110105|     Southwest|        Canada|    Metchosin|   British Columbia|              3|             1|                  0|             5|      70000.0| 8/22/1946|     M|No Discount|     Canadian Dollar|               Canada|       1892000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      28389|      0-1 Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest|        France|       Pantin|  Seine Saint Denis|              0|             0|                  3|             3|      20000.0|12/18/1964|     F|No Discount|        French Franc|               France|       1002000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|
# |      25863|      10+ Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest| United States|      Lebanon|             Oregon|              3|             1|                  0|             5|      40000.0| 12/3/1946|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|
# |      14501|      1-2 Miles|    Graduate Degree|              M|                   Road Bikes|  Road-650 Black, 62|    20101229|  20110110|   20110105|     Southwest| United States|Beverly Hills|         California|              2|             1|                  0|             4|      80000.0| 5/13/1938|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|
# |      11003|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Silv...|    20101229|  20110110|   20110105|     Southwest|     Australia|   North Ryde|    New South Wales|              1|             0|                  0|             0|      70000.0| 2/15/1968|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|
# |      27645|     5-10 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 44|    20101230|  20110111|   20110106|     Southwest| United States|     Coronado|         California|              4|             1|                  3|             1|     120000.0| 8/18/1961|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      16624|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|    20101230|  20110111|   20110106|     Southwest|     Australia|        Perth|    South Australia|              3|             0|                  0|             0|      90000.0| 7/27/1972|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      11005|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Blac...|    20101230|  20110111|   20110106|     Southwest|     Australia|East Brisbane|         Queensland|              1|             1|                  0|             0|      70000.0|  8/5/1965|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3374.99|       3374.99|                 0.0|           0.0|            1898.09|         1898.09|    3374.99| 270.0|  84.37|  00:00.0|00:00.0| 00:00.0|
# |      11011|      10+ Miles|          Bachelors|              M|               Mountain Bikes|Mountain-100 Silv...|    20101230|  20110111|   20110106|     Southwest|     Australia|East Brisbane|         Queensland|              4|             1|                  4|             4|      60000.0| 11/4/1963|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|
# |      27621|      1-2 Miles|    Graduate Degree|              S|                   Road Bikes|    Road-150 Red, 48|    20101231|  20110112|   20110107|     Southwest| United States| Santa Monica|         California|              4|             0|                  0|             0|     160000.0| 1/27/1964|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      27616|      2-5 Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 48|    20101231|  20110112|   20110107|     Southwest| United States|  Lemon Grove|         California|              4|             1|                  2|             3|     120000.0|12/11/1965|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      20042|      1-2 Miles|          Bachelors|              M|                   Road Bikes|    Road-650 Red, 52|    20101231|  20110112|   20110107|     Southwest|United Kingdom|    Liverpool|            England|              0|             1|                  1|             1|      40000.0|  5/4/1974|     M|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|
# |      16351|      1-2 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 52|    20101231|  20110112|   20110107|     Southwest|     Australia|  Rockhampton|         Queensland|              2|             0|                  0|             2|      80000.0|  7/7/1954|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      16517|      2-5 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 56|    20101231|  20110112|   20110107|     Southwest|     Australia|   Wollongong|    New South Wales|              0|             1|                  1|             1|      10000.0| 3/19/1976|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      27606|      0-1 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 56|    20110101|  20110113|   20110108|     Southwest| United States|    Milwaukie|             Oregon|              0|             0|                  1|             2|      70000.0| 5/27/1957|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      13513|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|    20110101|  20110113|   20110108|     Southwest|       Germany|        Werne|Nordrhein-Westfalen|              0|             1|                  0|             1|      30000.0|  9/8/1941|     F|No Discount|       Deutsche Mark|              Germany|        993000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      27601|      2-5 Miles|Partial High School|              S|                   Road Bikes|    Road-150 Red, 62|    20110102|  20110114|   20110109|     Southwest| United States|      Burbank|         California|              3|             0|                  1|             3|      60000.0|11/10/1953|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      13591|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|    20110102|  20110114|   20110109|     Southwest|United Kingdom|         York|            England|              3|             1|                  5|             0|     170000.0| 5/25/1953|     F|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      16483|     5-10 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 56|    20110102|  20110114|   20110109|     Southwest|     Australia|    Melbourne|           Victoria|              2|             1|                  0|             2|      40000.0|10/17/1950|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# |      16529|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|    20110102|  20110114|   20110109|     Southwest|     Australia|     Goulburn|    New South Wales|              0|             1|                  0|             0|      20000.0| 7/28/1977|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+
# only showing top 20 rows
# ['CustomerKey',
#  'CommuteDistance',
#  'EnglishEducation',
#  'marital statust',
#  'EnglishProductSubcategoryName',
#  'EnglishProductName',
#  'OrderDateKey',
#  'DueDateKey',
#  'ShipDateKey',
#  'Sales Terirory',
#  'Country',
#  'CITY',
#  'Province',
#  'NumberCarsOwned',
#  'HouseOwnerFlag',
#  'number  fo children',
#  'total children',
#  'annual income',
#  'birthdate',
#  'Gender',
#  'promo name',
#  'CurrencyName',
#  'SalesTerritoryCountry',
#  'SalesAmountQuote',
#  'OrderQuantity',
#  'UnitPrice',
#  'ExtendedAmount',
#  'UnitPriceDiscountPct',
#  'DiscountAmount',
#  'ProductStandardCost',
#  'TotalProductCost',
#  'SalesAmount',
#  'TaxAmt',
#  'Freight',
#  'OrderDate',
#  'DueDate',
#  'ShipDate']

# %% [markdown]
# ## SUMMARY STATISTICS

# %%
sales_filtered.summary().show()
# Out:
# +-------+------------------+---------------+-------------------+---------------+-----------------------------+--------------------+-------------------+-------------------+--------------------+--------------+-------------+-------+--------+------------------+-------------------+-------------------+------------------+------------------+---------+------+--------------------+--------------------+---------------------+------------------+-------------+------------------+------------------+--------------------+--------------+-------------------+------------------+------------------+-----------------+------------------+---------+-------+--------+
# |summary|       CustomerKey|CommuteDistance|   EnglishEducation|marital statust|EnglishProductSubcategoryName|  EnglishProductName|       OrderDateKey|         DueDateKey|         ShipDateKey|Sales Terirory|      Country|   CITY|Province|   NumberCarsOwned|     HouseOwnerFlag|number  fo children|    total children|     annual income|birthdate|Gender|          promo name|        CurrencyName|SalesTerritoryCountry|  SalesAmountQuote|OrderQuantity|         UnitPrice|    ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|  TotalProductCost|       SalesAmount|           TaxAmt|           Freight|OrderDate|DueDate|ShipDate|
# +-------+------------------+---------------+-------------------+---------------+-----------------------------+--------------------+-------------------+-------------------+--------------------+--------------+-------------+-------+--------+------------------+-------------------+-------------------+------------------+------------------+---------+------+--------------------+--------------------+---------------------+------------------+-------------+------------------+------------------+--------------------+--------------+-------------------+------------------+------------------+-----------------+------------------+---------+-------+--------+
# |  count|             60398|          60398|              60398|          60398|                        60398|               60398|              60398|              60398|               60398|         60398|        60398|  60398|   60398|             60398|              60398|              60398|             60398|             60398|    60398| 60398|               60398|               60398|                60398|             60398|        60398|             60398|             60398|               60398|         60398|              60398|             60398|             60398|            60398|             60398|    60398|  60398|   60398|
# |   mean|18841.685420047022|           NULL|               NULL|           NULL|                         NULL|                NULL|2.012973493314348E7|2.013010416608166E7|2.0129938434186563E7|          NULL|         NULL|   NULL|    NULL|1.5091890459949004| 0.6904036557501904| 1.0803172290473195|1.8507400907314813|59715.056789959934|     NULL|  NULL|                NULL|                NULL|                 NULL|1765600.6821417927|          1.0|486.08692158688973|486.08692158688973|                 0.0|           0.0| 286.06672505710344|286.06672505710344|486.08692158688973|38.88771316930886|12.150600682140105|     NULL|   NULL|    NULL|
# | stddev| 5432.430404014212|           NULL|               NULL|           NULL|                         NULL|                NULL|  4745.050337698708|  4985.453229313065|   4851.060708328251|          NULL|         NULL|   NULL|    NULL| 1.154163183836871|0.46233103605665216|  1.585963507690431|1.6210704169731007| 33065.42683679108|     NULL|  NULL|                NULL|                NULL|                 NULL| 730450.9556387102|          0.0| 928.4898783294751| 928.4898783294751|                 0.0|           0.0|  552.4567824117311| 552.4567824117311| 928.4898783294751|74.27934171567871|23.212760885284574|     NULL|   NULL|    NULL|
# |    min|             11000|      0-1 Miles|          Bachelors|              M|                   Bike Racks|        AWC Logo Cap|           20101229|           20110110|            20110105|       Central|    Australia|Ballard| Alabama|                 0|                  0|                  0|                 0|           10000.0| 1/1/1939|     F|         No Discount|   Australian Dollar|            Australia|          867000.0|            1|              2.29|              2.29|                 0.0|           0.0|               0.86|              0.86|              2.29|             0.18|              0.06|  00:00.0|00:00.0| 00:00.0|
# |    25%|             14002|           NULL|               NULL|           NULL|                         NULL|                NULL|           20130403|           20130415|            20130410|          NULL|         NULL|   NULL|    NULL|                 1|                  0|                  0|                 0|           30000.0|     NULL|  NULL|                NULL|                NULL|                 NULL|          993000.0|            1|              7.95|              7.95|                 0.0|           0.0|               2.97|              2.97|              7.95|             0.64|               0.2|     NULL|   NULL|    NULL|
# |    50%|             18141|           NULL|               NULL|           NULL|                         NULL|                NULL|           20130714|           20130726|            20130721|          NULL|         NULL|   NULL|    NULL|                 2|                  1|                  0|                 2|           60000.0|     NULL|  NULL|                NULL|                NULL|                 NULL|         1892000.0|            1|             29.99|             29.99|                 0.0|           0.0|              11.22|             11.22|             29.99|              2.4|              0.75|     NULL|   NULL|    NULL|
# |    75%|             23428|           NULL|               NULL|           NULL|                         NULL|                NULL|           20131018|           20131030|            20131025|          NULL|         NULL|   NULL|    NULL|                 2|                  1|                  2|                 3|           80000.0|     NULL|  NULL|                NULL|                NULL|                 NULL|         2427000.0|            1|            539.99|            539.99|                 0.0|           0.0|             294.58|            294.58|            539.99|             43.2|              13.5|     NULL|   NULL|    NULL|
# |    max|             29483|     5-10 Miles|Partial High School|              S|                        Vests|Women's Mountain ...|           20140128|           20140209|            20140204|United Kingdom|United States|   York| Yveline|                 4|                  1|                  5|                 5|          170000.0| 9/9/1979|     M|Volume Discount 1...|United Kingdom Pound|        United States|         4750000.0|            1|           3578.27|           3578.27|                 0.0|           0.0|            2171.29|           2171.29|           3578.27|           286.26|             89.46|  00:00.0|00:00.0| 00:00.0|
# +-------+------------------+---------------+-------------------+---------------+-----------------------------+--------------------+-------------------+-------------------+--------------------+--------------+-------------+-------+--------+------------------+-------------------+-------------------+------------------+------------------+---------+------+--------------------+--------------------+---------------------+------------------+-------------+------------------+------------------+--------------------+--------------+-------------------+------------------+------------------+-----------------+------------------+---------+-------+--------+

# %%
sales_filtered.summary().toPandas()
# Out:
#   summary         CustomerKey CommuteDistance     EnglishEducation  \
# 0   count               60398           60398                60398
# 1    mean  18841.685420047022            None                 None
# 2  stddev   5432.430404014212            None                 None
# 3     min               11000       0-1 Miles            Bachelors
# 4     25%               14002            None                 None
# 5     50%               18141            None                 None
# 6     75%               23428            None                 None
# 7     max               29483      5-10 Miles  Partial High School
#
#   marital statust EnglishProductSubcategoryName          EnglishProductName  \
# 0           60398                         60398                       60398
# 1            None                          None                        None
# 2            None                          None                        None
# 3               M                    Bike Racks                AWC Logo Cap
# 4            None                          None                        None
# 5            None                          None                        None
# 6            None                          None                        None
# 7               S                         Vests  Women's Mountain Shorts, S
#
#           OrderDateKey           DueDateKey           ShipDateKey  ...  \
# 0                60398                60398                 60398  ...
# 1  2.012973493314348E7  2.013010416608166E7  2.0129938434186563E7  ...
# 2    4745.050337698708    4985.453229313065     4851.060708328251  ...
# 3             20101229             20110110              20110105  ...
# 4             20130403             20130415              20130410  ...
# 5             20130714             20130726              20130721  ...
# 6             20131018             20131030              20131025  ...
# 7             20140128             20140209              20140204  ...
#
#   UnitPriceDiscountPct DiscountAmount ProductStandardCost    TotalProductCost  \
# 0                60398          60398               60398               60398
# 1                  0.0            0.0  286.06672505710344  286.06672505710344
# 2                  0.0            0.0   552.4567824117311   552.4567824117311
# 3                  0.0            0.0                0.86                0.86
# 4                  0.0            0.0                2.97                2.97
# 5                  0.0            0.0               11.22               11.22
# 6                  0.0            0.0              294.58              294.58
# 7                  0.0            0.0             2171.29             2171.29
#
#           SalesAmount             TaxAmt             Freight OrderDate  \
# 0               60398              60398               60398     60398
# 1  486.08692158688973  38.88771316930886  12.150600682140105      None
# 2   928.4898783294751  74.27934171567871  23.212760885284574      None
# 3                2.29               0.18                0.06   00:00.0
# 4                7.95               0.64                 0.2      None
# 5               29.99                2.4                0.75      None
# 6              539.99               43.2                13.5      None
# 7             3578.27             286.26               89.46   00:00.0
#
#    DueDate ShipDate
# 0    60398    60398
# 1     None     None
# 2     None     None
# 3  00:00.0  00:00.0
# 4     None     None
# 5     None     None
# 6     None     None
# 7  00:00.0  00:00.0
#
# [8 rows x 38 columns]

# %% [markdown]
# **CustomerKey:**
# The **CustomerKey** serves as a unique identifier for each customer, ranging from 11,000 to 29,483, with an average of approximately 18,841.69. The standard deviation of around 5,432.43 indicates some variability in customer identifiers, but the values are within a reasonable range.
#
# **Sales Metrics:**
# The primary focus is on sales-related metrics. The **SalesAmount** demonstrates substantial diversity, ranging from a minimum of 2.29 to a maximum of 3,578.27. This suggests a wide range of transactions, possibly reflecting different products, order sizes, or currencies.
#
# **Pricing and Discounts:**
# The **UnitPrice** statistics highlight a diverse pricing structure. The median (**50%**) value of 29.99 indicates that half of the entries have a unit price below this threshold, while the maximum unit price is 3,578.27. The **ExtendedAmount** statistics follow a similar pattern, representing the extended cost for each unit.
#
# Notably, the **DiscountAmount** and **UnitPriceDiscountPct** show minimal variation, with a consistent value of 0.0 for the mean, standard deviation, and all percentiles. This suggests that discounts are generally not applied or are negligible across the dataset. Further investigation into the discount policy or specific product categories might provide additional context.
#
# **Temporal Aspects:**
# The temporal aspects, such as **OrderDate**, **DueDate**, and **ShipDate**, are represented in a timestamp format. While the summary provides information about counts and basic statistics, additional analysis is required to extract meaningful insights into temporal trends, seasonality, or potential delays in order processing.
#
# In conclusion, these extensive summary statistics offer a comprehensive view of the numeric features in the dataset, providing insights into customer identifiers, sales metrics, pricing structures, and potential patterns in temporal aspects. Further exploratory data analysis (EDA) and visualization can uncover more nuanced patterns and trends in the data.

# %% [markdown]
# # visualizations

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'sales_filtered' is your Spark DataFrame containing the filtered data

# Convert Spark DataFrame to Pandas DataFrame
sales_filtered_pandas = sales_filtered.toPandas()

# Count the occurrences of each unique value in 'CommuteDistance'
commute_counts = sales_filtered_pandas['CommuteDistance'].value_counts()
print(commute_counts)
# Create a bar plot
plt.figure(figsize=(10, 6))
commute_counts.plot(kind='bar', color='skyblue')
plt.title('Count of CommuteDistance')
plt.xlabel('CommuteDistance')
plt.ylabel('Count')
plt.show()
# Out:
# CommuteDistance
# 0-1 Miles     21307
# 5-10 Miles    10615
# 1-2 Miles     10170
# 2-5 Miles     10084
# 10+ Miles      8222
# Name: count, dtype: int64

# %% [markdown]
# The summary provides a comprehensive overview of the 'CommuteDistance' variable in the dataset, shedding light on the distances customers cover to reach the store. The 'CommuteDistance' variable represents the various ranges of distances that customers travel, and the count for each category is presented, offering insights into the distribution of commuting distances within the dataset.
#
# The most common commuting distance is '0-1 Miles,' with a substantial count of 21,307 instances. This indicates that a significant portion of customers resides very close to the store, perhaps within a one-mile radius. Following closely is '5-10 Miles,' which has an occurrence of 10,615. This suggests that a considerable number of customers are willing to travel a moderate distance to access the store. '1-2 Miles' and '2-5 Miles' exhibit similar counts, both falling in the range of 10,000 instances, indicating a balanced distribution of customers covering distances within the 1-5 mile range.
#
# Interestingly, there is also a notable count for '10+ Miles,' with 8,222 instances. This signifies that a substantial proportion of customers are willing to travel significant distances, possibly because they find the store offerings or services compelling enough to justify a longer commute. The distribution across these categories unveils the diversity in customer commuting behaviors, showcasing a mix of local customers and those who are willing to travel greater distances.
#
# Analyzing commuting patterns is crucial for retailers to tailor marketing strategies, optimize store locations, and enhance customer experiences. For instance, stores in proximity to residential areas with a high count of '0-1 Miles' commuters might benefit from localized marketing efforts, while those attracting '10+ Miles' commuters could focus on initiatives to retain and attract customers from a broader geographical area.
#
# In conclusion, the 'CommuteDistance' summary provides valuable insights into the spatial dynamics of customer behavior, guiding retailers in making informed decisions to better serve their diverse customer base. Understanding the distribution of commuting distances is pivotal for creating targeted and effective business strategies that cater to the unique needs and preferences of customers with varying travel patterns.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pyspark.sql import SparkSession

# Assuming 'sales_filtered' is your Spark DataFrame
# Convert it to a Pandas DataFrame to make plotting easier
sales_pd = sales_filtered.toPandas()

# Plotting the bar plot for 'EnglishEducation'
education_counts = sales_pd['EnglishEducation'].value_counts()
education_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of English Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()
print(education_counts)
# Out:
# EnglishEducation
# Bachelors              18144
# Partial College        16623
# Graduate Degree        10603
# High School            10320
# Partial High School     4708
# Name: count, dtype: int64

# %% [markdown]
# The 'EnglishEducation' column in the dataset reveals the diverse educational backgrounds of the customers. This information is crucial for understanding the demographic composition of the customer base and tailoring business strategies to align with the varying needs and preferences of different education groups.
#
# 1. **Bachelors (18,144 customers):**
#    This category represents individuals who have completed a bachelor's degree. They may have a more in-depth understanding of specific fields, potentially influencing their purchasing decisions and preferences. Businesses could target this group with products and marketing messages that appeal to their higher educational attainment.
#
# 2. **Partial College (16,623 customers):**
#    Customers falling into the Partial College category have attended college but may not have completed a degree. This group represents individuals with some higher education experience, and businesses may consider offering products or services that cater to their specific needs or challenges.
#
# 3. **Graduate Degree (10,603 customers):**
#    This category includes customers with advanced degrees such as master's or doctoral degrees. Individuals with graduate degrees may have different preferences and purchasing behaviors, potentially seeking higher-end or specialized products and services.
#
# 4. **High School (10,320 customers):**
#    Customers in this category have completed high school education. Understanding the preferences of this group is essential for businesses offering products or services that appeal to a broader audience, as high school graduates represent a sizable portion of the customer base.
#
# 5. **Partial High School (4,708 customers):**
#    This group comprises individuals with some high school education but who did not complete their high school degree. Businesses might consider the economic factors and preferences that influence the purchasing behavior of this demographic.
#
# In-depth analysis of the 'EnglishEducation' data enables businesses to create targeted marketing campaigns, personalized product recommendations, and customer experiences that resonate with the educational diversity within their customer base. Moreover, this information can contribute to customer segmentation strategies, helping businesses identify and serve the unique needs of each education group effectively.
#
# The bar plot visually represents the distribution of customers across these education categories, offering a quick and intuitive overview of the dataset's educational landscape. If you have specific questions or if there's a particular aspect you'd like to explore further, feel free to let me know!

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# Assuming your data is in a Spark DataFrame named 'sales_filtered'
# Initialize Spark session
spark = SparkSession.builder.master("local").appName("BarPlot").getOrCreate()

# Aggregating counts for each category
columns_to_plot = ['marital statust', 'EnglishProductSubcategoryName', 'EnglishProductName',
                    'Sales Terirory', 'Country', 'CITY', 'Province', 'NumberCarsOwned',
                    'HouseOwnerFlag', 'number  fo children', 'total children', 'annual income',
                    'Gender', 'promo name', 'CurrencyName', 'SalesTerritoryCountry']

agg_data = []

for column in columns_to_plot:
    column_counts = sales_filtered.groupBy(column).count().collect()
    column_data = [(row[column], row['count']) for row in column_counts]
    agg_data.append((column, column_data))

# Create bar plots using Pandas and Matplotlib
for column, data in agg_data:
    df = pd.DataFrame(data, columns=[column, 'Count'])
    df = df.sort_values(by='Count', ascending=False)
    
    plt.figure(figsize=(10, 6))
    plt.bar(df[column], df['Count'])
    plt.title(f'Bar Plot for {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
from pyspark.sql.functions import count
from pyspark.sql import functions as F

# Assuming your data is in a Spark DataFrame named 'sales_filtered'
columns_to_plot = ['marital statust', 'EnglishProductSubcategoryName', 'EnglishProductName',
                    'Sales Terirory', 'Country', 'CITY', 'Province', 'NumberCarsOwned',
                    'HouseOwnerFlag', 'number  fo children', 'total children', 'annual income',
                    'Gender', 'promo name', 'CurrencyName', 'SalesTerritoryCountry']

# Create a summary table for each column
summary_table = []

for column in columns_to_plot:
    column_summary = (sales_filtered
                      .groupBy(column)
                      .agg(F.count('*').alias('Count'))
                      .orderBy(F.desc('Count'))
                      .collect())
    summary_table.append((column, column_summary))

# Display the summary table
for column, data in summary_table:
    print(f"\nSummary for {column}:\n")
    print(f"{column}\t|\tCount")
    print("-" * 30)
    for row in data:
        print(f"{row[column]}\t|\t{row['Count']}")
    print("\n")
# Out:
# Summary for marital statust:
#
# marital statust	|	Count
# ------------------------------
# M	|	33273
# S	|	27125
#
#
#
# Summary for EnglishProductSubcategoryName:
#
# EnglishProductSubcategoryName	|	Count
# ------------------------------
# Tires and Tubes	|	17332
# Road Bikes	|	8068
# Bottles and Cages	|	7981
# Helmets	|	6440
# Mountain Bikes	|	4970
# Jerseys	|	3332
# Caps	|	2190
# Touring Bikes	|	2167
# Fenders	|	2121
# Gloves	|	1430
# Shorts	|	1019
# Cleaners	|	908
# Hydration Packs	|	733
# Socks	|	568
# Vests	|	562
# Bike Racks	|	328
# Bike Stands	|	249
#
#
#
# Summary for EnglishProductName:
#
# EnglishProductName	|	Count
# ------------------------------
# Water Bottle - 30 oz.	|	4244
# Patch Kit/8 Patches	|	3191
# Mountain Tire Tube	|	3095
# Road Tire Tube	|	2376
# Sport-100 Helmet, Red	|	2230
# AWC Logo Cap	|	2190
# Sport-100 Helmet, Blue	|	2125
# Fender Set - Mountain	|	2121
# Sport-100 Helmet, Black	|	2085
# Mountain Bottle Cage	|	2025
# Road Bottle Cage	|	1712
# Touring Tire Tube	|	1488
# HL Mountain Tire	|	1396
# ML Mountain Tire	|	1161
# LL Road Tire	|	1044
# Touring Tire	|	935
# ML Road Tire	|	926
# Bike Wash - Dissolver	|	908
# LL Mountain Tire	|	862
# HL Road Tire	|	858
# Hydration Pack - 70 oz.	|	733
# Mountain-200 Black, 46	|	620
# Mountain-200 Black, 42	|	614
# Mountain-200 Silver, 38	|	596
# Mountain-200 Black, 38	|	582
# Mountain-200 Silver, 46	|	580
# Mountain-200 Silver, 42	|	560
# Half-Finger Gloves, M	|	499
# Half-Finger Gloves, S	|	488
# Long-Sleeve Logo Jersey, L	|	452
# Half-Finger Gloves, L	|	443
# Long-Sleeve Logo Jersey, M	|	442
# Long-Sleeve Logo Jersey, S	|	429
# Long-Sleeve Logo Jersey, XL	|	413
# Short-Sleeve Classic Jersey, XL	|	409
# Short-Sleeve Classic Jersey, M	|	407
# Short-Sleeve Classic Jersey, S	|	406
# Road-750 Black, 52	|	386
# Short-Sleeve Classic Jersey, L	|	374
# Women's Mountain Shorts, L	|	363
# Road-750 Black, 48	|	363
# Road-750 Black, 44	|	360
# Women's Mountain Shorts, M	|	352
# Road-150 Red, 48	|	337
# Road-150 Red, 62	|	336
# Road-750 Black, 58	|	334
# Hitch Rack - 4-Bike	|	328
# Road-250 Black, 52	|	319
# Road-250 Red, 58	|	306
# Road-550-W Yellow, 42	|	306
# Women's Mountain Shorts, S	|	304
# Road-150 Red, 52	|	302
# Racing Socks, M	|	298
# Road-250 Black, 48	|	298
# Road-150 Red, 56	|	295
# Road-550-W Yellow, 44	|	287
# Road-150 Red, 44	|	281
# Road-250 Black, 44	|	271
# Road-250 Black, 58	|	270
# Racing Socks, L	|	270
# Road-550-W Yellow, 38	|	270
# Road-550-W Yellow, 40	|	266
# Road-550-W Yellow, 48	|	261
# All-Purpose Bike Stand	|	249
# Road-350-W Yellow, 40	|	246
# Road-350-W Yellow, 42	|	235
# Road-350-W Yellow, 48	|	232
# Road-350-W Yellow, 44	|	216
# Classic Vest, M	|	199
# Classic Vest, L	|	195
# Touring-1000 Blue, 46	|	177
# Touring-1000 Yellow, 46	|	172
# Classic Vest, S	|	168
# Road-250 Red, 48	|	162
# Touring-1000 Blue, 54	|	160
# Touring-1000 Yellow, 54	|	158
# Touring-1000 Yellow, 50	|	151
# Touring-1000 Blue, 50	|	150
# Mountain-400-W Silver, 38	|	148
# Touring-1000 Blue, 60	|	147
# Road-250 Red, 44	|	144
# Touring-1000 Yellow, 60	|	140
# Mountain-400-W Silver, 46	|	138
# Road-250 Red, 52	|	133
# Mountain-400-W Silver, 42	|	129
# Mountain-400-W Silver, 40	|	128
# Touring-2000 Blue, 50	|	106
# Touring-2000 Blue, 46	|	97
# Road-650 Black, 52	|	89
# Road-650 Red, 48	|	88
# Touring-2000 Blue, 54	|	88
# Touring-2000 Blue, 60	|	81
# Road-650 Black, 60	|	76
# Road-650 Black, 58	|	76
# Road-650 Red, 62	|	75
# Road-650 Red, 58	|	74
# Road-650 Red, 44	|	72
# Road-650 Black, 62	|	65
# Touring-3000 Blue, 62	|	64
# Road-650 Black, 44	|	63
# Road-650 Red, 52	|	61
# Mountain-100 Black, 44	|	60
# Road-650 Black, 48	|	60
# Touring-3000 Yellow, 44	|	59
# Touring-3000 Yellow, 50	|	59
# Mountain-100 Silver, 38	|	58
# Mountain-500 Black, 44	|	58
# Touring-3000 Blue, 58	|	57
# Mountain-100 Black, 48	|	57
# Mountain-500 Black, 48	|	56
# Touring-3000 Blue, 54	|	55
# Touring-3000 Blue, 44	|	53
# Road-650 Red, 60	|	53
# Touring-3000 Yellow, 62	|	50
# Mountain-500 Silver, 48	|	50
# Mountain-100 Silver, 44	|	49
# Mountain-500 Black, 42	|	49
# Mountain-100 Black, 38	|	49
# Touring-3000 Blue, 50	|	48
# Mountain-500 Silver, 52	|	48
# Touring-3000 Yellow, 54	|	48
# Mountain-500 Black, 40	|	48
# Touring-3000 Yellow, 58	|	47
# Mountain-500 Silver, 42	|	45
# Mountain-500 Silver, 40	|	45
# Mountain-100 Black, 42	|	45
# Mountain-100 Silver, 42	|	42
# Mountain-500 Black, 52	|	41
# Mountain-500 Silver, 44	|	39
# Mountain-100 Silver, 48	|	36
#
#
#
# Summary for Sales Terirory:
#
# Sales Terirory	|	Count
# ------------------------------
# Central	|	20128
# Southwest	|	11917
# France	|	8630
# Northwest	|	7941
# Northeast	|	6959
# Southeast	|	3087
# United Kingdom	|	1736
#
#
#
# Summary for Country:
#
# Country	|	Count
# ------------------------------
# United States	|	21344
# Australia	|	13345
# Canada	|	7620
# United Kingdom	|	6906
# Germany	|	5625
# France	|	5558
#
#
#
# Summary for CITY:
#
# CITY	|	Count
# ------------------------------
# London	|	1579
# Paris	|	1174
# Cliffside	|	918
# Chula Vista	|	583
# Berlin	|	583
# Burien	|	579
# Berkeley	|	567
# Bellingham	|	566
# Shawnee	|	563
# Concord	|	559
# N. Vancouver	|	552
# Beaverton	|	547
# Bellflower	|	537
# Burlingame	|	535
# Burbank	|	532
# Langley	|	516
# Metchosin	|	503
# Port Hammond	|	502
# Bremerton	|	494
# Beverly Hills	|	485
# Haney	|	484
# Colma	|	484
# Victoria	|	482
# Royal Oak	|	479
# Langford	|	463
# Sooke	|	432
# Oak Bay	|	426
# York	|	420
# Warrnambool	|	416
# Wollongong	|	411
# Port Macquarie	|	405
# Caloundra	|	405
# Geelong	|	403
# Townsville	|	401
# Sydney	|	399
# Bendigo	|	396
# Sunbury	|	396
# Melbourne	|	394
# Hobart	|	393
# Brisbane	|	389
# Vancouver	|	388
# Coffs Harbour	|	387
# Cranbourne	|	385
# Hervey Bay	|	373
# Goulburn	|	370
# Rockhampton	|	369
# Hamburg	|	368
# Newton	|	365
# Gold Coast	|	364
# Melton	|	363
# Westminster	|	361
# Coronado	|	356
# Newcastle	|	344
# Les Ulis	|	323
# Hawthorne	|	311
# St. Leonards	|	307
# Matraville	|	305
# Oxford	|	302
# North Ryde	|	300
# Lemon Grove	|	299
# Lebanon	|	298
# Lavender Bay	|	297
# Lane Cove	|	296
# Perth	|	296
# Milwaukie	|	296
# South Melbourne	|	295
# Rhodes	|	295
# North Sydney	|	295
# Seaford	|	295
# Downey	|	295
# Frankfurt	|	293
# Cloverdale	|	293
# Springwood	|	291
# East Brisbane	|	291
# Glendale	|	290
# Issaquah	|	289
# Warrington	|	289
# Malabar	|	287
# Grossmont	|	287
# Darlinghurst	|	286
# Silverwater	|	285
# München	|	285
# Palo Alto	|	283
# Woodland Hills	|	281
# Santa Monica	|	280
# Milsons Point	|	279
# Findon	|	278
# Torrance	|	277
# San Diego	|	276
# Paderborn	|	274
# Edmonds	|	272
# Lincoln Acres	|	271
# El Cajon	|	270
# Corvallis	|	268
# La Jolla	|	265
# Puyallup	|	265
# Walla Walla	|	265
# Kirkland	|	262
# Novato	|	262
# Long Beach	|	262
# Lynnwood	|	261
# National City	|	260
# Salem	|	260
# Portland	|	259
# San Gabriel	|	258
# Olympia	|	258
# Spring Valley	|	257
# Marysville	|	254
# Oakland	|	251
# Imperial Beach	|	251
# Tacoma	|	251
# Lake Oswego	|	251
# Yakima	|	249
# Santa Cruz	|	248
# Redmond	|	247
# Milton Keynes	|	247
# West Covina	|	246
# Los Angeles	|	240
# Woodburn	|	240
# Renton	|	240
# Everett	|	237
# San Carlos	|	234
# Daly City	|	234
# Seattle	|	234
# Sedro Woolley	|	231
# Newport Beach	|	230
# Lakewood	|	229
# Redwood City	|	228
# Spokane	|	227
# Port Orchard	|	227
# Oregon City	|	226
# W. Linn	|	225
# Watford	|	222
# Runcorn	|	208
# Mill Valley	|	204
# Gateshead	|	203
# Peterborough	|	203
# Saint Ouen	|	203
# Bury	|	202
# Stoke-on-Trent	|	199
# Billericay	|	198
# Metz	|	196
# Esher-Molesey	|	194
# Orleans	|	193
# Roubaix	|	192
# Neunkirchen	|	191
# Leeds	|	191
# Ingolstadt	|	190
# Newcastle upon Tyne	|	190
# Fremont	|	189
# Cheltenham	|	188
# Tremblay-en-France	|	188
# Ballard	|	186
# Kirkby	|	183
# Villeneuve-d'Ascq	|	178
# Pantin	|	177
# Solingen	|	176
# Stuttgart	|	176
# Darmstadt	|	175
# Hof	|	175
# Chatou	|	174
# Bobigny	|	174
# Werne	|	172
# Saarlouis	|	171
# Erlangen	|	170
# Frankfurt am Main	|	169
# Dunkerque	|	162
# Versailles	|	161
# Kassel	|	161
# Colombes	|	160
# Bottrop	|	160
# Bonn	|	159
# Saint-Denis	|	156
# Lille	|	153
# Drancy	|	152
# Burnaby	|	150
# Saint Germain en Laye	|	149
# Cergy	|	134
# San Francisco	|	131
# Birmingham	|	121
# Berkshire	|	117
# Woolston	|	115
# Berks	|	114
# Wokingham	|	113
# Münster	|	112
# Liverpool	|	112
# Gloucestershire	|	111
# Offenbach	|	111
# Essen	|	110
# Colomiers	|	106
# W. York	|	104
# Lancaster	|	104
# West Sussex	|	103
# Leipzig	|	103
# Kiel	|	102
# Duesseldorf	|	100
# Oxon	|	100
# Eilenburg	|	100
# Bracknell	|	100
# Mühlheim	|	99
# Roissy en Brie	|	99
# Lieusaint	|	99
# Maidenhead	|	98
# Sulzbach Taunus	|	98
# Verrieres Le Buisson	|	97
# Hannover	|	96
# Courbevoie	|	95
# Braunschweig	|	94
# Saarbrücken	|	93
# Salzgitter	|	92
# Grevenbroich	|	92
# Dresden	|	91
# High Wycombe	|	90
# Cambridge	|	89
# Reading	|	89
# Morangis	|	85
# Paris La Defense	|	85
# Poing	|	84
# Suresnes	|	83
# Sèvres	|	82
# Roncq	|	81
# Orly	|	80
# Croix	|	78
# Boulogne-sur-Mer	|	45
# Boulogne-Billancourt	|	44
# Calgary	|	33
# Chicago	|	12
# Basingstoke Hants	|	10
# Cincinnati	|	10
# Clearwater	|	9
# Bluffton	|	8
# Columbus	|	7
# College Station	|	6
# Clackamas	|	6
# Bothell	|	5
# Campbellsville	|	5
# Central Valley	|	5
# City Of Commerce	|	4
# Canoga Park	|	4
# Carrollton	|	4
# Camarillo	|	4
# Cheektowaga	|	4
# Citrus Heights	|	4
# Casper	|	4
# Bountiful	|	3
# Cedar City	|	3
# Chalk Riber	|	3
# Bell Gardens	|	3
# Cheyenne	|	3
# Branch	|	3
# Branson	|	3
# Billings	|	3
# Cedar Park	|	3
# Chandler	|	2
# Clarkston	|	2
# Charlotte	|	2
# Clay	|	2
# Carol Stream	|	2
# Baytown	|	2
# Carson	|	2
# Biloxi	|	2
# Chantilly	|	2
# Bradenton	|	2
# Cerritos	|	2
# Barstow	|	1
# Braintree	|	1
# Bellevue	|	1
# Byron	|	1
# Chehalis	|	1
#
#
#
# Summary for Province:
#
# Province	|	Count
# ------------------------------
# California	|	12248
# British Columbia	|	7584
# England	|	6906
# Washington	|	6101
# New South Wales	|	5839
# Victoria	|	3343
# Queensland	|	2903
# Oregon	|	2876
# Saarland	|	1403
# Nordrhein-Westfalen	|	1257
# Hessen	|	1210
# Seine (Paris)	|	1174
# Hamburg	|	926
# South Australia	|	867
# Seine Saint Denis	|	847
# Nord	|	844
# Bayern	|	729
# Hauts de Seine	|	549
# Essonne	|	505
# Yveline	|	484
# Tasmania	|	393
# Seine et Marne	|	198
# Moselle	|	196
# Loiret	|	193
# Val d'Oise	|	134
# Garonne (Haute)	|	106
# Brandenburg	|	100
# Val de Marne	|	80
# Charente-Maritime	|	75
# Somme	|	68
# Loir et Cher	|	60
# Pas de Calais	|	45
# Alberta	|	33
# Ohio	|	15
# Texas	|	15
# Illinois	|	14
# Florida	|	11
# New York	|	11
# South Carolina	|	8
# Georgia	|	7
# Wyoming	|	7
# Utah	|	6
# Kentucky	|	5
# Ontario	|	3
# Minnesota	|	3
# Missouri	|	3
# Montana	|	3
# North Carolina	|	2
# Arizona	|	2
# Alabama	|	2
# Mississippi	|	2
# Virginia	|	2
# Massachusetts	|	1
#
#
#
# Summary for NumberCarsOwned:
#
# NumberCarsOwned	|	Count
# ------------------------------
# 2	|	20522
# 1	|	15812
# 0	|	14068
# 3	|	5688
# 4	|	4308
#
#
#
# Summary for HouseOwnerFlag:
#
# HouseOwnerFlag	|	Count
# ------------------------------
# 1	|	41699
# 0	|	18699
#
#
#
# Summary for number  fo children:
#
# number  fo children	|	Count
# ------------------------------
# 0	|	35535
# 1	|	7695
# 2	|	5338
# 4	|	4216
# 3	|	4028
# 5	|	3586
#
#
#
# Summary for total children:
#
# total children	|	Count
# ------------------------------
# 0	|	17048
# 2	|	12285
# 1	|	11561
# 4	|	7748
# 3	|	7061
# 5	|	4695
#
#
#
# Summary for annual income:
#
# annual income	|	Count
# ------------------------------
# 60000.0	|	9470
# 40000.0	|	9181
# 70000.0	|	8267
# 30000.0	|	6994
# 20000.0	|	5128
# 80000.0	|	4848
# 10000.0	|	3352
# 90000.0	|	3143
# 50000.0	|	1977
# 100000.0	|	1955
# 130000.0	|	1906
# 110000.0	|	1715
# 120000.0	|	1242
# 170000.0	|	476
# 150000.0	|	385
# 160000.0	|	359
#
#
#
# Summary for Gender:
#
# Gender	|	Count
# ------------------------------
# M	|	30381
# F	|	30017
#
#
#
# Summary for promo name:
#
# promo name	|	Count
# ------------------------------
# No Discount	|	58247
# Volume Discount 11 to 14	|	2118
# Touring-3000 Promotion	|	20
# Touring-1000 Promotion	|	13
#
#
#
# Summary for CurrencyName:
#
# CurrencyName	|	Count
# ------------------------------
# US Dollar	|	33400
# Australian Dollar	|	12988
# Canadian Dollar	|	7135
# United Kingdom Pound	|	6740
# Deutsche Mark	|	76
# French Franc	|	59
#
#
#
# Summary for SalesTerritoryCountry:
#
# SalesTerritoryCountry	|	Count
# ------------------------------
# United States	|	21344
# Australia	|	13345
# Canada	|	7620
# United Kingdom	|	6906
# Germany	|	5625
# France	|	5558

# %% [markdown]
# Certainly! Let's delve into the customer data for a store, imagining it as a real-life scenario in a retail setting.
#
# ### Marital Status:
#
# In our store, we've got a diverse group of customers, and when it comes to marital status, it's interesting to note that we've got a healthy mix. The majority, about 33,273 customers, are happily married ('M'), while a significant number, 27,125, are navigating the world solo ('S'). This gives us a glimpse into the different lifestyles and shopping needs of our customer base.
#
# ### Product Preferences:
#
# Now, when it comes to products, we can see that our customers have a penchant for certain items. Tires and tubes are flying off the shelves, with a whopping 17,332 purchases. It seems like our biking community is pretty active! Road bikes, bottles, and cages are also quite popular, giving us insights into the recreational interests of our customers.
#
# ### Geographic Insights:
#
# Our customers are spread across different territories and countries, giving our store a global feel. 'Central' seems to be a hot spot, with 20,128 customers, possibly indicating a bustling location or effective marketing strategies in that area. The United States takes the lead in countries, with 21,344 customers, showcasing the widespread appeal of our products.
#
# ### Customer Demographics:
#
# Understanding our customers' profiles is crucial. Take 'California,' for example. It's not just a state; it's home to a whopping 12,248 customers. That's a significant chunk of our customer base, and tailoring our offerings to the Californian lifestyle could be a smart move.
#
# ### Lifestyle Choices:
#
# Knowing that a majority of our customers own two cars (20,522) might suggest that our store caters to a suburban or family-oriented demographic. Also, the fact that 41,699 customers own a house indicates a stable customer base. This information is gold when it comes to planning promotions or stocking products that align with homeowners' needs.
#
# ### Family Matters:
#
# Family dynamics play a role too. With 35,535 customers having no children, we might want to highlight products that cater to individual or couple lifestyles. On the flip side, 7,695 customers with one child and 5,338 with two children provide opportunities for family-oriented promotions.
#
# ### Financial Insights:
#
# Our customers' financial situations vary, and this impacts their spending habits. The $60,000 income bracket leads the pack with 9,470 customers. This information helps us tailor promotions or loyalty programs that resonate with the majority of our customer base.
#
# ### Shopping Behavior:
#
# It's fascinating to note that 'No Discount' is the go-to choice for the majority (58,247 customers). This aligns with general consumer behavior; people love a good deal, and offering discounts can be a powerful strategy to boost sales.
#
# ### Currency Matters:
#
# Considering the currency used, the dominance of US Dollars (33,400 transactions) suggests that the majority of our customers are making purchases in the United States. This could guide decisions related to international marketing efforts and currency-specific promotions.
#
# ### Real-world Application:
#
# Imagine our store as a neighborhood hub. In bustling locations like 'London' and 'Paris,' we're meeting the demands of city dwellers, while in 'California,' we're catering to a suburban lifestyle. Our promotions are enticing to both singles and families, and our product offerings align with the diverse interests of our global customer base.
#
# This in-depth analysis of our customer data not only helps us understand who our customers are but also empowers us to tailor our strategies to meet their needs and preferences, creating a shopping experience that feels personalized and welcoming.

# %% [markdown]
# # data date cleaning
# OrderDateKey	DueDateKey	ShipDateKey are dates columns stored in the format 20101229 where the first four are years the next two are months  and the last 2 are days of the weeks we will break down these date keys into a date format valid in python spark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, concat_ws, substring, to_date

# Assuming spark is your SparkSession and sales_filtered is your DataFrame
spark = SparkSession.builder.appName("example").getOrCreate()

# Extract year, month, and day components and concatenate them
sales_filtered = sales_filtered.withColumn(
    'OrderDateKey',
    to_date(
        concat_ws(
            '-',
            substring(sales_filtered['OrderDateKey'], 1, 4),  # Extract year
            substring(sales_filtered['OrderDateKey'], 5, 2),  # Extract month
            substring(sales_filtered['OrderDateKey'], 7, 2)   # Extract day
        ),
        'yyyy-MM-dd'
    )
)

# Repeat the process for DueDateKey and ShipDateKey
sales_filtered = sales_filtered.withColumn(
    'DueDateKey',
    to_date(
        concat_ws(
            '-',
            substring(sales_filtered['DueDateKey'], 1, 4),
            substring(sales_filtered['DueDateKey'], 5, 2),
            substring(sales_filtered['DueDateKey'], 7, 2)
        ),
        'yyyy-MM-dd'
    )
)

sales_filtered = sales_filtered.withColumn(
    'ShipDateKey',
    to_date(
        concat_ws(
            '-',
            substring(sales_filtered['ShipDateKey'], 1, 4),
            substring(sales_filtered['ShipDateKey'], 5, 2),
            substring(sales_filtered['ShipDateKey'], 7, 2)
        ),
        'yyyy-MM-dd'
    )
)

# Select and show the three date columns
sales_filtered.select('OrderDateKey', 'DueDateKey', 'ShipDateKey').show()
# Out:
# +------------+----------+-----------+
# |OrderDateKey|DueDateKey|ShipDateKey|
# +------------+----------+-----------+
# |  2010-12-29|2011-01-10| 2011-01-05|
# |  2010-12-29|2011-01-10| 2011-01-05|
# |  2010-12-29|2011-01-10| 2011-01-05|
# |  2010-12-29|2011-01-10| 2011-01-05|
# |  2010-12-29|2011-01-10| 2011-01-05|
# |  2010-12-30|2011-01-11| 2011-01-06|
# |  2010-12-30|2011-01-11| 2011-01-06|
# |  2010-12-30|2011-01-11| 2011-01-06|
# |  2010-12-30|2011-01-11| 2011-01-06|
# |  2010-12-31|2011-01-12| 2011-01-07|
# |  2010-12-31|2011-01-12| 2011-01-07|
# |  2010-12-31|2011-01-12| 2011-01-07|
# |  2010-12-31|2011-01-12| 2011-01-07|
# |  2010-12-31|2011-01-12| 2011-01-07|
# |  2011-01-01|2011-01-13| 2011-01-08|
# |  2011-01-01|2011-01-13| 2011-01-08|
# |  2011-01-02|2011-01-14| 2011-01-09|
# |  2011-01-02|2011-01-14| 2011-01-09|
# |  2011-01-02|2011-01-14| 2011-01-09|
# |  2011-01-02|2011-01-14| 2011-01-09|
# +------------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# # plots by date.
#
# her we see the year 2031 january to 2014 january as the best years with the highest sales .

# %%
order_dates_count = (
    sales_filtered
    .groupBy('OrderDateKey')
    .count()
    .orderBy('OrderDateKey')
)

# Convert the PySpark DataFrame to a Pandas DataFrame
order_dates_count_pd = order_dates_count.toPandas()

# Plot the count of order dates as a line plot
plt.figure(figsize=(15, 9))
plt.plot(order_dates_count_pd['OrderDateKey'], order_dates_count_pd['count'], marker='o', linestyle='-')
plt.xlabel('Order Date')
plt.ylabel('Count')
plt.title('Count of Orders by Date (Line Plot)')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %% [markdown]
# # adding days and month to the ddates
# here we will add day of the weeks to the orderdate so that we can have a clear undedrstanding of sales by day and month of the year.

# %%
from pyspark.sql.functions import month, dayofweek

# Assuming 'OrderDateKey' is the column containing the order dates
# Assuming 'OrderMonth' and 'OrderDayOfWeek' are the new column names

# Extract month and day of the week from 'OrderDateKey'
sales_filtered = (
    sales_filtered
    .withColumn('OrderMonth', month('OrderDateKey'))
    .withColumn('OrderDayOfWeek', dayofweek('OrderDateKey'))
)

# Show the updated DataFrame
sales_filtered.show()
# Out:
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+
# |CustomerKey|CommuteDistance|   EnglishEducation|marital statust|EnglishProductSubcategoryName|  EnglishProductName|OrderDateKey|DueDateKey|ShipDateKey|Sales Terirory|       Country|         CITY|           Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income| birthdate|Gender| promo name|        CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderDate|DueDate|ShipDate|OrderMonth|OrderDayOfWeek|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+
# |      21768|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|        Canada|    Metchosin|   British Columbia|              3|             1|                  0|             5|      70000.0| 8/22/1946|     M|No Discount|     Canadian Dollar|               Canada|       1892000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             4|
# |      28389|      0-1 Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|        France|       Pantin|  Seine Saint Denis|              0|             0|                  3|             3|      20000.0|12/18/1964|     F|No Discount|        French Franc|               France|       1002000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|
# |      25863|      10+ Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest| United States|      Lebanon|             Oregon|              3|             1|                  0|             5|      40000.0| 12/3/1946|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|
# |      14501|      1-2 Miles|    Graduate Degree|              M|                   Road Bikes|  Road-650 Black, 62|  2010-12-29|2011-01-10| 2011-01-05|     Southwest| United States|Beverly Hills|         California|              2|             1|                  0|             4|      80000.0| 5/13/1938|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|        12|             4|
# |      11003|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|     Australia|   North Ryde|    New South Wales|              1|             0|                  0|             0|      70000.0| 2/15/1968|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|
# |      27645|     5-10 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 44|  2010-12-30|2011-01-11| 2011-01-06|     Southwest| United States|     Coronado|         California|              4|             1|                  3|             1|     120000.0| 8/18/1961|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             5|
# |      16624|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|        Perth|    South Australia|              3|             0|                  0|             0|      90000.0| 7/27/1972|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             5|
# |      11005|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Blac...|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|East Brisbane|         Queensland|              1|             1|                  0|             0|      70000.0|  8/5/1965|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3374.99|       3374.99|                 0.0|           0.0|            1898.09|         1898.09|    3374.99| 270.0|  84.37|  00:00.0|00:00.0| 00:00.0|        12|             5|
# |      11011|      10+ Miles|          Bachelors|              M|               Mountain Bikes|Mountain-100 Silv...|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|East Brisbane|         Queensland|              4|             1|                  4|             4|      60000.0| 11/4/1963|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             5|
# |      27621|      1-2 Miles|    Graduate Degree|              S|                   Road Bikes|    Road-150 Red, 48|  2010-12-31|2011-01-12| 2011-01-07|     Southwest| United States| Santa Monica|         California|              4|             0|                  0|             0|     160000.0| 1/27/1964|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|
# |      27616|      2-5 Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 48|  2010-12-31|2011-01-12| 2011-01-07|     Southwest| United States|  Lemon Grove|         California|              4|             1|                  2|             3|     120000.0|12/11/1965|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|
# |      20042|      1-2 Miles|          Bachelors|              M|                   Road Bikes|    Road-650 Red, 52|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|United Kingdom|    Liverpool|            England|              0|             1|                  1|             1|      40000.0|  5/4/1974|     M|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|        12|             6|
# |      16351|      1-2 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 52|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|     Australia|  Rockhampton|         Queensland|              2|             0|                  0|             2|      80000.0|  7/7/1954|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|
# |      16517|      2-5 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 56|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|     Australia|   Wollongong|    New South Wales|              0|             1|                  1|             1|      10000.0| 3/19/1976|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|
# |      27606|      0-1 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 56|  2011-01-01|2011-01-13| 2011-01-08|     Southwest| United States|    Milwaukie|             Oregon|              0|             0|                  1|             2|      70000.0| 5/27/1957|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             7|
# |      13513|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-01|2011-01-13| 2011-01-08|     Southwest|       Germany|        Werne|Nordrhein-Westfalen|              0|             1|                  0|             1|      30000.0|  9/8/1941|     F|No Discount|       Deutsche Mark|              Germany|        993000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             7|
# |      27601|      2-5 Miles|Partial High School|              S|                   Road Bikes|    Road-150 Red, 62|  2011-01-02|2011-01-14| 2011-01-09|     Southwest| United States|      Burbank|         California|              3|             0|                  1|             3|      60000.0|11/10/1953|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|
# |      13591|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|United Kingdom|         York|            England|              3|             1|                  5|             0|     170000.0| 5/25/1953|     F|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|
# |      16483|     5-10 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 56|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|     Australia|    Melbourne|           Victoria|              2|             1|                  0|             2|      40000.0|10/17/1950|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|
# |      16529|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|     Australia|     Goulburn|    New South Wales|              0|             1|                  0|             0|      20000.0| 7/28/1977|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ## summary of the orders by month and day of the week
#
# The presented table provides a comprehensive overview of sales data, offering insights into consumer behavior and purchase patterns across different temporal dimensions—specifically, by month and day of the week. These insights, derived from real-world scenarios, can guide strategic decision-making for businesses seeking to optimize their operations and marketing strategies.
#
# Examining the 'OrderMonth' column, it is evident that there is a noticeable fluctuation in order counts throughout the year. For instance, the months of June, October, and December record higher order counts compared to other months. This trend aligns with common retail patterns observed in the real world. June might see increased sales due to mid-year promotions or summer-related products. October, often associated with holiday preparations, experiences a surge in purchases, while December reflects the holiday shopping season, contributing to a peak in order counts.
#
# On the other hand, the 'OrderDayOfWeek' column provides insights into consumer behavior during the week. Interestingly, there is a relatively consistent order count across weekdays, with Monday having the highest count and Sunday the lowest. This aligns with conventional wisdom that suggests consumers are more active in making purchases at the beginning of the week, potentially influenced by factors such as weekend promotions, planning for the workweek, or the release of new products.
#
# These observations can guide businesses in optimizing their marketing and operational strategies. For instance, during high-order count months, businesses may focus on targeted marketing campaigns or inventory management to meet increased demand. On Mondays, when order counts are higher, businesses might consider launching special promotions or releasing new products to capitalize on heightened consumer activity at the start of the week.
#
# Understanding these patterns empowers businesses to allocate resources effectively, enhance customer engagement, and tailor promotions to specific periods, thereby maximizing revenue potential. The ability to discern trends in consumer behavior based on temporal factors is a valuable tool in the dynamic landscape of retail, facilitating adaptability and responsiveness to customer preferences.

# %%
from pyspark.sql.functions import count

# Group by OrderMonth and OrderDayOfWeek, and count the occurrences
order_month_count = (
    sales_filtered
    .groupBy('OrderMonth')
    .agg(count('*').alias('OrderCount'))
    .orderBy('OrderMonth')
)

order_day_of_week_count = (
    sales_filtered
    .groupBy('OrderDayOfWeek')
    .agg(count('*').alias('OrderCount'))
    .orderBy('OrderDayOfWeek')
)

# Show the results
order_month_count.show()
order_day_of_week_count.show()
# Out:
# +----------+----------+
# |OrderMonth|OrderCount|
# +----------+----------+
# |         1|      4028|
# |         2|      3857|
# |         3|      4449|
# |         4|      4355|
# |         5|      4780|
# |         6|      5573|
# |         7|      5105|
# |         8|      5352|
# |         9|      5070|
# |        10|      5834|
# |        11|      5756|
# |        12|      6239|
# +----------+----------+
#
# +--------------+----------+
# |OrderDayOfWeek|OrderCount|
# +--------------+----------+
# |             1|      8596|
# |             2|      8732|
# |             3|      8949|
# |             4|      8585|
# |             5|      8550|
# |             6|      8504|
# |             7|      8482|
# +--------------+----------+

# %%
import matplotlib.pyplot as plt

# Convert PySpark DataFrame to Pandas for plotting
order_month_pd = order_month_count.toPandas()
order_day_of_week_pd = order_day_of_week_count.toPandas()

# Plotting the count of order month
plt.figure(figsize=(10, 5))
plt.bar(order_month_pd['OrderMonth'], order_month_pd['OrderCount'])
plt.xlabel('Order Month')
plt.ylabel('Order Count')
plt.title('Count of Orders by Month')
plt.show()

# Plotting the count of order day of the week
plt.figure(figsize=(10, 5))
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.bar(order_day_of_week_pd['OrderDayOfWeek'], order_day_of_week_pd['OrderCount'])
plt.xlabel('Order Day of the Week')
plt.ylabel('Order Count')
plt.title('Count of Orders by Day of the Week')
plt.xticks(order_day_of_week_pd['OrderDayOfWeek'], days_of_week)  # Set the x-axis ticks to display weekdays
plt.show()

# %%
# Plotting the count of order month
plt.figure(figsize=(10, 5))
plt.bar(order_month_pd['OrderMonth'], order_month_pd['OrderCount'])
plt.xlabel('Order Month')
plt.ylabel('Order Count')
plt.title('Count of Orders by Month')
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import concat, col, lit
import matplotlib.pyplot as plt

# Assuming spark is your SparkSession and sales_filtered is your DataFrame
spark = SparkSession.builder.appName("example").getOrCreate()

# Create a new column 'OrderDayMonth' by combining 'OrderMonth' and 'OrderDayOfWeek'
sales_filtered = sales_filtered.withColumn('OrderDayMonth', concat(col('OrderMonth'), lit('-'), col('OrderDayOfWeek')))

# Group by the new column and count the occurrences
order_day_month_count = sales_filtered.groupBy('OrderDayMonth').count()

# Convert PySpark DataFrame to Pandas for plotting
order_day_month_count_pd = order_day_month_count.toPandas()

# Plotting the count of orders by day of the week and month
plt.figure(figsize=(20, 7))
plt.bar(order_day_month_count_pd['OrderDayMonth'], order_day_month_count_pd['count'])
plt.xlabel('Order Day of the Week and Month')
plt.ylabel('Order Count')
plt.title('Count of Orders by Day of the Week and Month')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Assuming 'UnitPrice' and 'CommuteDistance' are the actual column names in your DataFrame
unit_price_column = 'UnitPrice'
commute_distance_column = 'CommuteDistance'

# Select the relevant columns from the DataFrame
plot_data = sales_filtered.select(commute_distance_column, unit_price_column).toPandas()

# Set up the barplot
plt.figure(figsize=(12, 6))
sns.barplot(x=commute_distance_column, y=unit_price_column, data=plot_data)
plt.xlabel('Commute Distance')
plt.ylabel('Unit Price')
plt.title('Unit Price by Commute Distance')
plt.show()

# %%
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
import seaborn as sns

# Create a Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Assuming 'UnitPrice' is the actual column name in your DataFrame
unit_price_column = 'UnitPrice'

# List of categorical columns
categorical_columns = [
    'CommuteDistance', 'EnglishEducation', 'marital statust',
    'EnglishProductSubcategoryName', 'EnglishProductName', 'Sales Terirory',
    'Country', 'CITY', 'Province', 'Gender', 'promo name', 'CurrencyName',
    'SalesTerritoryCountry'
]

# Set up subplots
fig, axes = plt.subplots(nrows=len(categorical_columns), ncols=1, figsize=(12, 6 * len(categorical_columns)))

# Iterate through each categorical column and create bar plots
for i, column in enumerate(categorical_columns):
    # Select the relevant columns from the DataFrame
    plot_data = sales_filtered.select(column, unit_price_column).toPandas()

    # Create a bar plot
    sns.barplot(x=column, y=unit_price_column, data=plot_data, ax=axes[i])
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Unit Price')
    axes[i].set_title(f'Unit Price by {column}')

# Adjust layout for better readability
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.functions import avg

# List of categorical columns
categorical_columns = ['CommuteDistance', 'EnglishEducation', 'marital statust',
                        'EnglishProductSubcategoryName', 'EnglishProductName', 'Sales Terirory',
                        'Country', 'CITY', 'Province', 'Gender', 'promo name', 'CurrencyName',
                        'SalesTerritoryCountry']

# Create an empty Pandas DataFrame to store results
result_pd = pd.DataFrame(columns=['Category', 'AverageUnitPrice'])

# Iterate through each categorical column and calculate the average UnitPrice
for column in categorical_columns:
    # Calculate average UnitPrice for each category using Spark
    avg_unit_price_df = sales_filtered.groupBy(column).agg(avg('UnitPrice').alias('AverageUnitPrice')).toPandas()
    
    # Add the results to the Pandas DataFrame
    avg_unit_price_df['Category'] = column
    result_pd = pd.concat([result_pd, avg_unit_price_df], ignore_index=True)
    
    # Print the DataFrame for the current column
    print(f"\nDataFrame for {column}:\n")
    print(avg_unit_price_df)

# Create subplots
fig, axes = plt.subplots(nrows=len(categorical_columns), ncols=1, figsize=(10, 5 * len(categorical_columns)))

# Iterate through each categorical column and create bar plots
for i, column in enumerate(categorical_columns):
    # Filter data for the current column
    plot_data = result_pd[result_pd['Category'] == column]
    
    # Create a bar plot
    sns.barplot(x=column, y='AverageUnitPrice', data=plot_data, ax=axes[i])
    
    # Set plot labels and title
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Average Unit Price')
    axes[i].set_title(f'Average Unit Price by {column}')

    # Print the DataFrame used for the plot
    print(f"\nDataFrame used for the plot of {column}:\n")
    print(plot_data)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\neste\AppData\Local\Temp\ipykernel_6296\208723743.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_pd = pd.concat([result_pd, avg_unit_price_df], ignore_index=True)
# DataFrame for CommuteDistance:
#
#   CommuteDistance  AverageUnitPrice         Category
# 0       0-1 Miles        526.005179  CommuteDistance
# 1       10+ Miles        456.192473  CommuteDistance
# 2       2-5 Miles        492.415180  CommuteDistance
# 3      5-10 Miles        460.965439  CommuteDistance
# 4       1-2 Miles        446.569147  CommuteDistance
#
# DataFrame for EnglishEducation:
#
#       EnglishEducation  AverageUnitPrice          Category
# 0          High School        449.421139  EnglishEducation
# 1  Partial High School        347.579720  EnglishEducation
# 2      Graduate Degree        515.001450  EnglishEducation
# 3      Partial College        464.629918  EnglishEducation
# 4            Bachelors        545.642798  EnglishEducation
#
# DataFrame for marital statust:
#
#   marital statust  AverageUnitPrice         Category
# 0               M        456.447452  marital statust
# 1               S        522.444306  marital statust
#
# DataFrame for EnglishProductSubcategoryName:
#
#    EnglishProductSubcategoryName  AverageUnitPrice  \
# 0                 Mountain Bikes       2002.567559
# 1                Hydration Packs         54.990000
# 2                     Road Bikes       1799.774851
# 3              Bottles and Cages          7.116676
# 4                          Vests         63.500000
# 5                        Helmets         34.990000
# 6                        Jerseys         51.905966
# 7                         Gloves         24.490000
# 8                  Touring Bikes       1774.250600
# 9                     Bike Racks        120.000000
# 10                       Fenders         21.980000
# 11                          Caps          8.990000
# 12                        Shorts         69.990000
# 13                   Bike Stands        159.000000
# 14               Tires and Tubes         14.166243
# 15                      Cleaners          7.950000
# 16                         Socks          8.990000
#
#                          Category
# 0   EnglishProductSubcategoryName
# 1   EnglishProductSubcategoryName
# 2   EnglishProductSubcategoryName
# 3   EnglishProductSubcategoryName
# 4   EnglishProductSubcategoryName
# 5   EnglishProductSubcategoryName
# 6   EnglishProductSubcategoryName
# 7   EnglishProductSubcategoryName
# 8   EnglishProductSubcategoryName
# 9   EnglishProductSubcategoryName
# 10  EnglishProductSubcategoryName
# 11  EnglishProductSubcategoryName
# 12  EnglishProductSubcategoryName
# 13  EnglishProductSubcategoryName
# 14  EnglishProductSubcategoryName
# 15  EnglishProductSubcategoryName
# 16  EnglishProductSubcategoryName
#
# DataFrame for EnglishProductName:
#
#                  EnglishProductName  AverageUnitPrice            Category
# 0            Mountain-200 Black, 42       2220.101678  EnglishProductName
# 1           Touring-1000 Yellow, 46       2384.070000  EnglishProductName
# 2             Touring-1000 Blue, 54       2384.070000  EnglishProductName
# 3    Short-Sleeve Classic Jersey, S         53.990000  EnglishProductName
# 4        Women's Mountain Shorts, S         69.990000  EnglishProductName
# ..                              ...               ...                 ...
# 125         Hydration Pack - 70 oz.         54.990000  EnglishProductName
# 126              Road-250 Black, 48       2319.482919  EnglishProductName
# 127          Mountain-100 Black, 42       3374.990000  EnglishProductName
# 128             Hitch Rack - 4-Bike        120.000000  EnglishProductName
# 129     Long-Sleeve Logo Jersey, XL         49.990000  EnglishProductName
#
# [130 rows x 3 columns]
#
# DataFrame for Sales Terirory:
#
#    Sales Terirory  AverageUnitPrice        Category
# 0          France         28.392086  Sales Terirory
# 1       Northwest         52.814624  Sales Terirory
# 2       Southeast        643.753213  Sales Terirory
# 3         Central         87.166949  Sales Terirory
# 4       Southwest       2083.859922  Sales Terirory
# 5  United Kingdom         49.990000  Sales Terirory
# 6       Northeast          4.648572  Sales Terirory
#
# DataFrame for Country:
#
#           Country  AverageUnitPrice Category
# 0         Germany        514.544420  Country
# 1          France        475.713879  Country
# 2   United States        439.926440  Country
# 3          Canada        259.559697  Country
# 4       Australia        678.980946  Country
# 5  United Kingdom        491.125433  Country
#
# DataFrame for CITY:
#
#                 CITY  AverageUnitPrice Category
# 0    South Melbourne        697.616373     CITY
# 1            Edmonds        385.329816     CITY
# 2         Cranbourne        479.285870     CITY
# 3          Bountiful       1451.870000     CITY
# 4          Cliffside        230.510784     CITY
# ..               ...               ...      ...
# 264           Casper        303.615000     CITY
# 265        Chantilly         19.990000     CITY
# 266        Bradenton         19.490000     CITY
# 267         Cerritos        572.740000     CITY
# 268   Central Valley         10.188000     CITY
#
# [269 rows x 3 columns]
#
# DataFrame for Province:
#
#                Province  AverageUnitPrice  Category
# 0                  Utah        736.596667  Province
# 1                  Ohio         23.945333  Province
# 2                Oregon        407.159809  Province
# 3                  Nord        463.744301  Province
# 4                 Texas        119.273333  Province
# 5           Brandenburg        579.192100  Province
# 6       South Australia        713.097901  Province
# 7              Victoria        681.994056  Province
# 8         Pas de Calais        252.064889  Province
# 9                Bayern        548.651289  Province
# 10           Val d'Oise        348.924627  Province
# 11       Hauts de Seine        479.810929  Province
# 12              Alberta        680.842424  Province
# 13                Somme        434.636471  Province
# 14      New South Wales        673.828698  Province
# 15           Washington        404.400662  Province
# 16             Illinois        202.006429  Province
# 17              Hamburg        517.414536  Province
# 18       Seine et Marne        554.218333  Province
# 19  Nordrhein-Westfalen        450.369372  Province
# 20              Moselle        479.827755  Province
# 21              Ontario         12.320000  Province
# 22         Val de Marne        355.976500  Province
# 23              Georgia        236.988571  Province
# 24               Hessen        547.192802  Province
# 25    Charente-Maritime        459.223067  Province
# 26     British Columbia        257.824384  Province
# 27       North Carolina          3.640000  Province
# 28              Wyoming       1016.430000  Province
# 29              Essonne        553.063723  Province
# 30              Arizona       1052.010000  Province
# 31    Seine Saint Denis        448.028052  Province
# 32        Massachusetts       2049.100000  Province
# 33             Tasmania        610.529033  Province
# 34              Florida        705.537273  Province
# 35              England        491.125433  Province
# 36           Queensland        684.951784  Province
# 37           California        466.546208  Province
# 38             Saarland        519.659950  Province
# 39              Yveline        555.092603  Province
# 40         Loir et Cher        357.895667  Province
# 41               Loiret        474.419223  Province
# 42        Seine (Paris)        459.732368  Province
# 43      Garonne (Haute)        515.487925  Province
# 44            Minnesota         30.426667  Province
# 45             Missouri         27.153333  Province
# 46              Montana         30.693333  Province
# 47              Alabama         18.645000  Province
# 48             Kentucky         43.392000  Province
# 49             New York        374.926364  Province
# 50          Mississippi         41.295000  Province
# 51       South Carolina        304.365000  Province
# 52             Virginia         19.990000  Province
#
# DataFrame for Gender:
#
#   Gender  AverageUnitPrice Category
# 0      F        493.507649   Gender
# 1      M        478.755104   Gender
#
# DataFrame for promo name:
#
#                  promo name  AverageUnitPrice    Category
# 0               No Discount        468.824272  promo name
# 1    Touring-3000 Promotion        742.350000  promo name
# 2  Volume Discount 11 to 14        946.756653  promo name
# 3    Touring-1000 Promotion       2384.070000  promo name
#
# DataFrame for CurrencyName:
#
#            CurrencyName  AverageUnitPrice      Category
# 0     Australian Dollar        696.950125  CurrencyName
# 1          French Franc       3060.537458  CurrencyName
# 2       Canadian Dollar        253.190960  CurrencyName
# 3  United Kingdom Pound        502.722510  CurrencyName
# 4         Deutsche Mark       3128.750132  CurrencyName
# 5             US Dollar        439.924124  CurrencyName
#
# DataFrame for SalesTerritoryCountry:
#
#   SalesTerritoryCountry  AverageUnitPrice               Category
# 0               Germany        514.544420  SalesTerritoryCountry
# 1                France        475.713879  SalesTerritoryCountry
# 2         United States        439.926440  SalesTerritoryCountry
# 3                Canada        259.559697  SalesTerritoryCountry
# 4             Australia        678.980946  SalesTerritoryCountry
# 5        United Kingdom        491.125433  SalesTerritoryCountry
#
# DataFrame used for the plot of CommuteDistance:
#
#           Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 0  CommuteDistance        526.005179       0-1 Miles              NaN
# 1  CommuteDistance        456.192473       10+ Miles              NaN
# 2  CommuteDistance        492.415180       2-5 Miles              NaN
# 3  CommuteDistance        460.965439      5-10 Miles              NaN
# 4  CommuteDistance        446.569147       1-2 Miles              NaN
#
#   marital statust EnglishProductSubcategoryName EnglishProductName  \
# 0             NaN                           NaN                NaN
# 1             NaN                           NaN                NaN
# 2             NaN                           NaN                NaN
# 3             NaN                           NaN                NaN
# 4             NaN                           NaN                NaN
#
#   Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 0            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 1            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 2            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 3            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 4            NaN     NaN  NaN      NaN    NaN        NaN          NaN
#
#   SalesTerritoryCountry
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# DataFrame used for the plot of EnglishEducation:
#
#            Category  AverageUnitPrice CommuteDistance     EnglishEducation  \
# 5  EnglishEducation        449.421139             NaN          High School
# 6  EnglishEducation        347.579720             NaN  Partial High School
# 7  EnglishEducation        515.001450             NaN      Graduate Degree
# 8  EnglishEducation        464.629918             NaN      Partial College
# 9  EnglishEducation        545.642798             NaN            Bachelors
#
#   marital statust EnglishProductSubcategoryName EnglishProductName  \
# 5             NaN                           NaN                NaN
# 6             NaN                           NaN                NaN
# 7             NaN                           NaN                NaN
# 8             NaN                           NaN                NaN
# 9             NaN                           NaN                NaN
#
#   Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 5            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 6            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 7            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 8            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 9            NaN     NaN  NaN      NaN    NaN        NaN          NaN
#
#   SalesTerritoryCountry
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
#
# DataFrame used for the plot of marital statust:
#
#            Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 10  marital statust        456.447452             NaN              NaN
# 11  marital statust        522.444306             NaN              NaN
#
#    marital statust EnglishProductSubcategoryName EnglishProductName  \
# 10               M                           NaN                NaN
# 11               S                           NaN                NaN
#
#    Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 10            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 11            NaN     NaN  NaN      NaN    NaN        NaN          NaN
#
#    SalesTerritoryCountry
# 10                   NaN
# 11                   NaN
#
# DataFrame used for the plot of EnglishProductSubcategoryName:
#
#                          Category  AverageUnitPrice CommuteDistance  \
# 12  EnglishProductSubcategoryName       2002.567559             NaN
# 13  EnglishProductSubcategoryName         54.990000             NaN
# 14  EnglishProductSubcategoryName       1799.774851             NaN
# 15  EnglishProductSubcategoryName          7.116676             NaN
# 16  EnglishProductSubcategoryName         63.500000             NaN
# 17  EnglishProductSubcategoryName         34.990000             NaN
# 18  EnglishProductSubcategoryName         51.905966             NaN
# 19  EnglishProductSubcategoryName         24.490000             NaN
# 20  EnglishProductSubcategoryName       1774.250600             NaN
# 21  EnglishProductSubcategoryName        120.000000             NaN
# 22  EnglishProductSubcategoryName         21.980000             NaN
# 23  EnglishProductSubcategoryName          8.990000             NaN
# 24  EnglishProductSubcategoryName         69.990000             NaN
# 25  EnglishProductSubcategoryName        159.000000             NaN
# 26  EnglishProductSubcategoryName         14.166243             NaN
# 27  EnglishProductSubcategoryName          7.950000             NaN
# 28  EnglishProductSubcategoryName          8.990000             NaN
#
#    EnglishEducation marital statust EnglishProductSubcategoryName  \
# 12              NaN             NaN                Mountain Bikes
# 13              NaN             NaN               Hydration Packs
# 14              NaN             NaN                    Road Bikes
# 15              NaN             NaN             Bottles and Cages
# 16              NaN             NaN                         Vests
# 17              NaN             NaN                       Helmets
# 18              NaN             NaN                       Jerseys
# 19              NaN             NaN                        Gloves
# 20              NaN             NaN                 Touring Bikes
# 21              NaN             NaN                    Bike Racks
# 22              NaN             NaN                       Fenders
# 23              NaN             NaN                          Caps
# 24              NaN             NaN                        Shorts
# 25              NaN             NaN                   Bike Stands
# 26              NaN             NaN               Tires and Tubes
# 27              NaN             NaN                      Cleaners
# 28              NaN             NaN                         Socks
#
#    EnglishProductName Sales Terirory Country CITY Province Gender promo name  \
# 12                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 13                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 14                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 15                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 16                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 17                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 18                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 19                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 20                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 21                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 22                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 23                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 24                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 25                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 26                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 27                NaN            NaN     NaN  NaN      NaN    NaN        NaN
# 28                NaN            NaN     NaN  NaN      NaN    NaN        NaN
#
#    CurrencyName SalesTerritoryCountry
# 12          NaN                   NaN
# 13          NaN                   NaN
# 14          NaN                   NaN
# 15          NaN                   NaN
# 16          NaN                   NaN
# 17          NaN                   NaN
# 18          NaN                   NaN
# 19          NaN                   NaN
# 20          NaN                   NaN
# 21          NaN                   NaN
# 22          NaN                   NaN
# 23          NaN                   NaN
# 24          NaN                   NaN
# 25          NaN                   NaN
# 26          NaN                   NaN
# 27          NaN                   NaN
# 28          NaN                   NaN
#
# DataFrame used for the plot of EnglishProductName:
#
#                Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 29   EnglishProductName       2220.101678             NaN              NaN
# 30   EnglishProductName       2384.070000             NaN              NaN
# 31   EnglishProductName       2384.070000             NaN              NaN
# 32   EnglishProductName         53.990000             NaN              NaN
# 33   EnglishProductName         69.990000             NaN              NaN
# ..                  ...               ...             ...              ...
# 154  EnglishProductName         54.990000             NaN              NaN
# 155  EnglishProductName       2319.482919             NaN              NaN
# 156  EnglishProductName       3374.990000             NaN              NaN
# 157  EnglishProductName        120.000000             NaN              NaN
# 158  EnglishProductName         49.990000             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName  \
# 29              NaN                           NaN
# 30              NaN                           NaN
# 31              NaN                           NaN
# 32              NaN                           NaN
# 33              NaN                           NaN
# ..              ...                           ...
# 154             NaN                           NaN
# 155             NaN                           NaN
# 156             NaN                           NaN
# 157             NaN                           NaN
# 158             NaN                           NaN
#
#                  EnglishProductName Sales Terirory Country CITY Province  \
# 29           Mountain-200 Black, 42            NaN     NaN  NaN      NaN
# 30          Touring-1000 Yellow, 46            NaN     NaN  NaN      NaN
# 31            Touring-1000 Blue, 54            NaN     NaN  NaN      NaN
# 32   Short-Sleeve Classic Jersey, S            NaN     NaN  NaN      NaN
# 33       Women's Mountain Shorts, S            NaN     NaN  NaN      NaN
# ..                              ...            ...     ...  ...      ...
# 154         Hydration Pack - 70 oz.            NaN     NaN  NaN      NaN
# 155              Road-250 Black, 48            NaN     NaN  NaN      NaN
# 156          Mountain-100 Black, 42            NaN     NaN  NaN      NaN
# 157             Hitch Rack - 4-Bike            NaN     NaN  NaN      NaN
# 158     Long-Sleeve Logo Jersey, XL            NaN     NaN  NaN      NaN
#
#     Gender promo name CurrencyName SalesTerritoryCountry
# 29     NaN        NaN          NaN                   NaN
# 30     NaN        NaN          NaN                   NaN
# 31     NaN        NaN          NaN                   NaN
# 32     NaN        NaN          NaN                   NaN
# 33     NaN        NaN          NaN                   NaN
# ..     ...        ...          ...                   ...
# 154    NaN        NaN          NaN                   NaN
# 155    NaN        NaN          NaN                   NaN
# 156    NaN        NaN          NaN                   NaN
# 157    NaN        NaN          NaN                   NaN
# 158    NaN        NaN          NaN                   NaN
#
# [130 rows x 15 columns]
#
# DataFrame used for the plot of Sales Terirory:
#
#            Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 159  Sales Terirory         28.392086             NaN              NaN
# 160  Sales Terirory         52.814624             NaN              NaN
# 161  Sales Terirory        643.753213             NaN              NaN
# 162  Sales Terirory         87.166949             NaN              NaN
# 163  Sales Terirory       2083.859922             NaN              NaN
# 164  Sales Terirory         49.990000             NaN              NaN
# 165  Sales Terirory          4.648572             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 159             NaN                           NaN                NaN
# 160             NaN                           NaN                NaN
# 161             NaN                           NaN                NaN
# 162             NaN                           NaN                NaN
# 163             NaN                           NaN                NaN
# 164             NaN                           NaN                NaN
# 165             NaN                           NaN                NaN
#
#      Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 159          France     NaN  NaN      NaN    NaN        NaN          NaN
# 160       Northwest     NaN  NaN      NaN    NaN        NaN          NaN
# 161       Southeast     NaN  NaN      NaN    NaN        NaN          NaN
# 162         Central     NaN  NaN      NaN    NaN        NaN          NaN
# 163       Southwest     NaN  NaN      NaN    NaN        NaN          NaN
# 164  United Kingdom     NaN  NaN      NaN    NaN        NaN          NaN
# 165       Northeast     NaN  NaN      NaN    NaN        NaN          NaN
#
#     SalesTerritoryCountry
# 159                   NaN
# 160                   NaN
# 161                   NaN
# 162                   NaN
# 163                   NaN
# 164                   NaN
# 165                   NaN
#
# DataFrame used for the plot of Country:
#
#     Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 166  Country        514.544420             NaN              NaN
# 167  Country        475.713879             NaN              NaN
# 168  Country        439.926440             NaN              NaN
# 169  Country        259.559697             NaN              NaN
# 170  Country        678.980946             NaN              NaN
# 171  Country        491.125433             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 166             NaN                           NaN                NaN
# 167             NaN                           NaN                NaN
# 168             NaN                           NaN                NaN
# 169             NaN                           NaN                NaN
# 170             NaN                           NaN                NaN
# 171             NaN                           NaN                NaN
#
#     Sales Terirory         Country CITY Province Gender promo name  \
# 166            NaN         Germany  NaN      NaN    NaN        NaN
# 167            NaN          France  NaN      NaN    NaN        NaN
# 168            NaN   United States  NaN      NaN    NaN        NaN
# 169            NaN          Canada  NaN      NaN    NaN        NaN
# 170            NaN       Australia  NaN      NaN    NaN        NaN
# 171            NaN  United Kingdom  NaN      NaN    NaN        NaN
#
#     CurrencyName SalesTerritoryCountry
# 166          NaN                   NaN
# 167          NaN                   NaN
# 168          NaN                   NaN
# 169          NaN                   NaN
# 170          NaN                   NaN
# 171          NaN                   NaN
#
# DataFrame used for the plot of CITY:
#
#     Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 172     CITY        697.616373             NaN              NaN
# 173     CITY        385.329816             NaN              NaN
# 174     CITY        479.285870             NaN              NaN
# 175     CITY       1451.870000             NaN              NaN
# 176     CITY        230.510784             NaN              NaN
# ..       ...               ...             ...              ...
# 436     CITY        303.615000             NaN              NaN
# 437     CITY         19.990000             NaN              NaN
# 438     CITY         19.490000             NaN              NaN
# 439     CITY        572.740000             NaN              NaN
# 440     CITY         10.188000             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 172             NaN                           NaN                NaN
# 173             NaN                           NaN                NaN
# 174             NaN                           NaN                NaN
# 175             NaN                           NaN                NaN
# 176             NaN                           NaN                NaN
# ..              ...                           ...                ...
# 436             NaN                           NaN                NaN
# 437             NaN                           NaN                NaN
# 438             NaN                           NaN                NaN
# 439             NaN                           NaN                NaN
# 440             NaN                           NaN                NaN
#
#     Sales Terirory Country             CITY Province Gender promo name  \
# 172            NaN     NaN  South Melbourne      NaN    NaN        NaN
# 173            NaN     NaN          Edmonds      NaN    NaN        NaN
# 174            NaN     NaN       Cranbourne      NaN    NaN        NaN
# 175            NaN     NaN        Bountiful      NaN    NaN        NaN
# 176            NaN     NaN        Cliffside      NaN    NaN        NaN
# ..             ...     ...              ...      ...    ...        ...
# 436            NaN     NaN           Casper      NaN    NaN        NaN
# 437            NaN     NaN        Chantilly      NaN    NaN        NaN
# 438            NaN     NaN        Bradenton      NaN    NaN        NaN
# 439            NaN     NaN         Cerritos      NaN    NaN        NaN
# 440            NaN     NaN   Central Valley      NaN    NaN        NaN
#
#     CurrencyName SalesTerritoryCountry
# 172          NaN                   NaN
# 173          NaN                   NaN
# 174          NaN                   NaN
# 175          NaN                   NaN
# 176          NaN                   NaN
# ..           ...                   ...
# 436          NaN                   NaN
# 437          NaN                   NaN
# 438          NaN                   NaN
# 439          NaN                   NaN
# 440          NaN                   NaN
#
# [269 rows x 15 columns]
#
# DataFrame used for the plot of Province:
#
#      Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 441  Province        736.596667             NaN              NaN
# 442  Province         23.945333             NaN              NaN
# 443  Province        407.159809             NaN              NaN
# 444  Province        463.744301             NaN              NaN
# 445  Province        119.273333             NaN              NaN
# 446  Province        579.192100             NaN              NaN
# 447  Province        713.097901             NaN              NaN
# 448  Province        681.994056             NaN              NaN
# 449  Province        252.064889             NaN              NaN
# 450  Province        548.651289             NaN              NaN
# 451  Province        348.924627             NaN              NaN
# 452  Province        479.810929             NaN              NaN
# 453  Province        680.842424             NaN              NaN
# 454  Province        434.636471             NaN              NaN
# 455  Province        673.828698             NaN              NaN
# 456  Province        404.400662             NaN              NaN
# 457  Province        202.006429             NaN              NaN
# 458  Province        517.414536             NaN              NaN
# 459  Province        554.218333             NaN              NaN
# 460  Province        450.369372             NaN              NaN
# 461  Province        479.827755             NaN              NaN
# 462  Province         12.320000             NaN              NaN
# 463  Province        355.976500             NaN              NaN
# 464  Province        236.988571             NaN              NaN
# 465  Province        547.192802             NaN              NaN
# 466  Province        459.223067             NaN              NaN
# 467  Province        257.824384             NaN              NaN
# 468  Province          3.640000             NaN              NaN
# 469  Province       1016.430000             NaN              NaN
# 470  Province        553.063723             NaN              NaN
# 471  Province       1052.010000             NaN              NaN
# 472  Province        448.028052             NaN              NaN
# 473  Province       2049.100000             NaN              NaN
# 474  Province        610.529033             NaN              NaN
# 475  Province        705.537273             NaN              NaN
# 476  Province        491.125433             NaN              NaN
# 477  Province        684.951784             NaN              NaN
# 478  Province        466.546208             NaN              NaN
# 479  Province        519.659950             NaN              NaN
# 480  Province        555.092603             NaN              NaN
# 481  Province        357.895667             NaN              NaN
# 482  Province        474.419223             NaN              NaN
# 483  Province        459.732368             NaN              NaN
# 484  Province        515.487925             NaN              NaN
# 485  Province         30.426667             NaN              NaN
# 486  Province         27.153333             NaN              NaN
# 487  Province         30.693333             NaN              NaN
# 488  Province         18.645000             NaN              NaN
# 489  Province         43.392000             NaN              NaN
# 490  Province        374.926364             NaN              NaN
# 491  Province         41.295000             NaN              NaN
# 492  Province        304.365000             NaN              NaN
# 493  Province         19.990000             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 441             NaN                           NaN                NaN
# 442             NaN                           NaN                NaN
# 443             NaN                           NaN                NaN
# 444             NaN                           NaN                NaN
# 445             NaN                           NaN                NaN
# 446             NaN                           NaN                NaN
# 447             NaN                           NaN                NaN
# 448             NaN                           NaN                NaN
# 449             NaN                           NaN                NaN
# 450             NaN                           NaN                NaN
# 451             NaN                           NaN                NaN
# 452             NaN                           NaN                NaN
# 453             NaN                           NaN                NaN
# 454             NaN                           NaN                NaN
# 455             NaN                           NaN                NaN
# 456             NaN                           NaN                NaN
# 457             NaN                           NaN                NaN
# 458             NaN                           NaN                NaN
# 459             NaN                           NaN                NaN
# 460             NaN                           NaN                NaN
# 461             NaN                           NaN                NaN
# 462             NaN                           NaN                NaN
# 463             NaN                           NaN                NaN
# 464             NaN                           NaN                NaN
# 465             NaN                           NaN                NaN
# 466             NaN                           NaN                NaN
# 467             NaN                           NaN                NaN
# 468             NaN                           NaN                NaN
# 469             NaN                           NaN                NaN
# 470             NaN                           NaN                NaN
# 471             NaN                           NaN                NaN
# 472             NaN                           NaN                NaN
# 473             NaN                           NaN                NaN
# 474             NaN                           NaN                NaN
# 475             NaN                           NaN                NaN
# 476             NaN                           NaN                NaN
# 477             NaN                           NaN                NaN
# 478             NaN                           NaN                NaN
# 479             NaN                           NaN                NaN
# 480             NaN                           NaN                NaN
# 481             NaN                           NaN                NaN
# 482             NaN                           NaN                NaN
# 483             NaN                           NaN                NaN
# 484             NaN                           NaN                NaN
# 485             NaN                           NaN                NaN
# 486             NaN                           NaN                NaN
# 487             NaN                           NaN                NaN
# 488             NaN                           NaN                NaN
# 489             NaN                           NaN                NaN
# 490             NaN                           NaN                NaN
# 491             NaN                           NaN                NaN
# 492             NaN                           NaN                NaN
# 493             NaN                           NaN                NaN
#
#     Sales Terirory Country CITY             Province Gender promo name  \
# 441            NaN     NaN  NaN                 Utah    NaN        NaN
# 442            NaN     NaN  NaN                 Ohio    NaN        NaN
# 443            NaN     NaN  NaN               Oregon    NaN        NaN
# 444            NaN     NaN  NaN                 Nord    NaN        NaN
# 445            NaN     NaN  NaN                Texas    NaN        NaN
# 446            NaN     NaN  NaN          Brandenburg    NaN        NaN
# 447            NaN     NaN  NaN      South Australia    NaN        NaN
# 448            NaN     NaN  NaN             Victoria    NaN        NaN
# 449            NaN     NaN  NaN        Pas de Calais    NaN        NaN
# 450            NaN     NaN  NaN               Bayern    NaN        NaN
# 451            NaN     NaN  NaN           Val d'Oise    NaN        NaN
# 452            NaN     NaN  NaN       Hauts de Seine    NaN        NaN
# 453            NaN     NaN  NaN              Alberta    NaN        NaN
# 454            NaN     NaN  NaN                Somme    NaN        NaN
# 455            NaN     NaN  NaN      New South Wales    NaN        NaN
# 456            NaN     NaN  NaN           Washington    NaN        NaN
# 457            NaN     NaN  NaN             Illinois    NaN        NaN
# 458            NaN     NaN  NaN              Hamburg    NaN        NaN
# 459            NaN     NaN  NaN       Seine et Marne    NaN        NaN
# 460            NaN     NaN  NaN  Nordrhein-Westfalen    NaN        NaN
# 461            NaN     NaN  NaN              Moselle    NaN        NaN
# 462            NaN     NaN  NaN              Ontario    NaN        NaN
# 463            NaN     NaN  NaN         Val de Marne    NaN        NaN
# 464            NaN     NaN  NaN              Georgia    NaN        NaN
# 465            NaN     NaN  NaN               Hessen    NaN        NaN
# 466            NaN     NaN  NaN    Charente-Maritime    NaN        NaN
# 467            NaN     NaN  NaN     British Columbia    NaN        NaN
# 468            NaN     NaN  NaN       North Carolina    NaN        NaN
# 469            NaN     NaN  NaN              Wyoming    NaN        NaN
# 470            NaN     NaN  NaN              Essonne    NaN        NaN
# 471            NaN     NaN  NaN              Arizona    NaN        NaN
# 472            NaN     NaN  NaN    Seine Saint Denis    NaN        NaN
# 473            NaN     NaN  NaN        Massachusetts    NaN        NaN
# 474            NaN     NaN  NaN             Tasmania    NaN        NaN
# 475            NaN     NaN  NaN              Florida    NaN        NaN
# 476            NaN     NaN  NaN              England    NaN        NaN
# 477            NaN     NaN  NaN           Queensland    NaN        NaN
# 478            NaN     NaN  NaN           California    NaN        NaN
# 479            NaN     NaN  NaN             Saarland    NaN        NaN
# 480            NaN     NaN  NaN              Yveline    NaN        NaN
# 481            NaN     NaN  NaN         Loir et Cher    NaN        NaN
# 482            NaN     NaN  NaN               Loiret    NaN        NaN
# 483            NaN     NaN  NaN        Seine (Paris)    NaN        NaN
# 484            NaN     NaN  NaN      Garonne (Haute)    NaN        NaN
# 485            NaN     NaN  NaN            Minnesota    NaN        NaN
# 486            NaN     NaN  NaN             Missouri    NaN        NaN
# 487            NaN     NaN  NaN              Montana    NaN        NaN
# 488            NaN     NaN  NaN              Alabama    NaN        NaN
# 489            NaN     NaN  NaN             Kentucky    NaN        NaN
# 490            NaN     NaN  NaN             New York    NaN        NaN
# 491            NaN     NaN  NaN          Mississippi    NaN        NaN
# 492            NaN     NaN  NaN       South Carolina    NaN        NaN
# 493            NaN     NaN  NaN             Virginia    NaN        NaN
#
#     CurrencyName SalesTerritoryCountry
# 441          NaN                   NaN
# 442          NaN                   NaN
# 443          NaN                   NaN
# 444          NaN                   NaN
# 445          NaN                   NaN
# 446          NaN                   NaN
# 447          NaN                   NaN
# 448          NaN                   NaN
# 449          NaN                   NaN
# 450          NaN                   NaN
# 451          NaN                   NaN
# 452          NaN                   NaN
# 453          NaN                   NaN
# 454          NaN                   NaN
# 455          NaN                   NaN
# 456          NaN                   NaN
# 457          NaN                   NaN
# 458          NaN                   NaN
# 459          NaN                   NaN
# 460          NaN                   NaN
# 461          NaN                   NaN
# 462          NaN                   NaN
# 463          NaN                   NaN
# 464          NaN                   NaN
# 465          NaN                   NaN
# 466          NaN                   NaN
# 467          NaN                   NaN
# 468          NaN                   NaN
# 469          NaN                   NaN
# 470          NaN                   NaN
# 471          NaN                   NaN
# 472          NaN                   NaN
# 473          NaN                   NaN
# 474          NaN                   NaN
# 475          NaN                   NaN
# 476          NaN                   NaN
# 477          NaN                   NaN
# 478          NaN                   NaN
# 479          NaN                   NaN
# 480          NaN                   NaN
# 481          NaN                   NaN
# 482          NaN                   NaN
# 483          NaN                   NaN
# 484          NaN                   NaN
# 485          NaN                   NaN
# 486          NaN                   NaN
# 487          NaN                   NaN
# 488          NaN                   NaN
# 489          NaN                   NaN
# 490          NaN                   NaN
# 491          NaN                   NaN
# 492          NaN                   NaN
# 493          NaN                   NaN
#
# DataFrame used for the plot of Gender:
#
#     Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 494   Gender        493.507649             NaN              NaN
# 495   Gender        478.755104             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 494             NaN                           NaN                NaN
# 495             NaN                           NaN                NaN
#
#     Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 494            NaN     NaN  NaN      NaN      F        NaN          NaN
# 495            NaN     NaN  NaN      NaN      M        NaN          NaN
#
#     SalesTerritoryCountry
# 494                   NaN
# 495                   NaN
#
# DataFrame used for the plot of promo name:
#
#        Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 496  promo name        468.824272             NaN              NaN
# 497  promo name        742.350000             NaN              NaN
# 498  promo name        946.756653             NaN              NaN
# 499  promo name       2384.070000             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 496             NaN                           NaN                NaN
# 497             NaN                           NaN                NaN
# 498             NaN                           NaN                NaN
# 499             NaN                           NaN                NaN
#
#     Sales Terirory Country CITY Province Gender                promo name  \
# 496            NaN     NaN  NaN      NaN    NaN               No Discount
# 497            NaN     NaN  NaN      NaN    NaN    Touring-3000 Promotion
# 498            NaN     NaN  NaN      NaN    NaN  Volume Discount 11 to 14
# 499            NaN     NaN  NaN      NaN    NaN    Touring-1000 Promotion
#
#     CurrencyName SalesTerritoryCountry
# 496          NaN                   NaN
# 497          NaN                   NaN
# 498          NaN                   NaN
# 499          NaN                   NaN
#
# DataFrame used for the plot of CurrencyName:
#
#          Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 500  CurrencyName        696.950125             NaN              NaN
# 501  CurrencyName       3060.537458             NaN              NaN
# 502  CurrencyName        253.190960             NaN              NaN
# 503  CurrencyName        502.722510             NaN              NaN
# 504  CurrencyName       3128.750132             NaN              NaN
# 505  CurrencyName        439.924124             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 500             NaN                           NaN                NaN
# 501             NaN                           NaN                NaN
# 502             NaN                           NaN                NaN
# 503             NaN                           NaN                NaN
# 504             NaN                           NaN                NaN
# 505             NaN                           NaN                NaN
#
#     Sales Terirory Country CITY Province Gender promo name  \
# 500            NaN     NaN  NaN      NaN    NaN        NaN
# 501            NaN     NaN  NaN      NaN    NaN        NaN
# 502            NaN     NaN  NaN      NaN    NaN        NaN
# 503            NaN     NaN  NaN      NaN    NaN        NaN
# 504            NaN     NaN  NaN      NaN    NaN        NaN
# 505            NaN     NaN  NaN      NaN    NaN        NaN
#
#              CurrencyName SalesTerritoryCountry
# 500     Australian Dollar                   NaN
# 501          French Franc                   NaN
# 502       Canadian Dollar                   NaN
# 503  United Kingdom Pound                   NaN
# 504         Deutsche Mark                   NaN
# 505             US Dollar                   NaN
#
# DataFrame used for the plot of SalesTerritoryCountry:
#
#                   Category  AverageUnitPrice CommuteDistance EnglishEducation  \
# 506  SalesTerritoryCountry        514.544420             NaN              NaN
# 507  SalesTerritoryCountry        475.713879             NaN              NaN
# 508  SalesTerritoryCountry        439.926440             NaN              NaN
# 509  SalesTerritoryCountry        259.559697             NaN              NaN
# 510  SalesTerritoryCountry        678.980946             NaN              NaN
# 511  SalesTerritoryCountry        491.125433             NaN              NaN
#
#     marital statust EnglishProductSubcategoryName EnglishProductName  \
# 506             NaN                           NaN                NaN
# 507             NaN                           NaN                NaN
# 508             NaN                           NaN                NaN
# 509             NaN                           NaN                NaN
# 510             NaN                           NaN                NaN
# 511             NaN                           NaN                NaN
#
#     Sales Terirory Country CITY Province Gender promo name CurrencyName  \
# 506            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 507            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 508            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 509            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 510            NaN     NaN  NaN      NaN    NaN        NaN          NaN
# 511            NaN     NaN  NaN      NaN    NaN        NaN          NaN
#
#     SalesTerritoryCountry
# 506               Germany
# 507                France
# 508         United States
# 509                Canada
# 510             Australia
# 511        United Kingdom

# %% [markdown]
# The table summary provides the average unit price for different categories within specific columns such as CommuteDistance, EnglishEducation, marital status, EnglishProductSubcategoryName, Sales Territory, Country, promo name, and CurrencyName. Let's analyze each section:
#
# ### CommuteDistance:
# The average unit prices vary based on the distance customers commute. Notably, the highest average unit price is observed for customers with a commute distance of 0-1 Miles, suggesting that customers living very close tend to purchase higher-priced items.
#
# ### EnglishEducation:
# Customers with different education levels exhibit variations in their purchasing behavior. Notably, customers with a Graduate Degree or Bachelors tend to spend more on average compared to those with only a High School or Partial High School education.
#
# ### Marital Status:
# The average unit price varies between customers who are Single (S) and those who are Married (M). Married customers have a slightly higher average unit price, indicating potentially different spending patterns or preferences.
#
# ### EnglishProductSubcategoryName:
# The type of product subcategory also influences the average unit price. For instance, products like Mountain Bikes, Road Bikes, and Touring Bikes have higher average prices compared to items like Bottles and Cages or Cleaners.
#
# ### Sales Territory:
# Different sales territories exhibit varying average unit prices. For example, Southeast and Southwest territories have notably higher average unit prices compared to other regions, suggesting regional preferences or economic factors.
#
# ### Country:
# Customers from different countries show variations in their average spending. For instance, customers from Australia tend to have a higher average unit price compared to customers from Canada.
#
# ### Promo Name:
# The presence or absence of discounts, as indicated by different promo names, impacts the average unit price. Products associated with promotions like "Touring-1000 Promotion" or "Volume Discount 11 to 14" have significantly higher average prices.
#
# ### Currency Name:
# The choice of currency also plays a role in determining the average unit price. For instance, products priced in French Franc or Deutsche Mark have notably higher average unit prices compared to products priced in US Dollars.
#
# **Explanation:**
# These insights can help in tailoring marketing strategies, pricing models, and inventory management based on the observed variations in average unit prices across different customer segments, product categories, and regions. Understanding these patterns can contribute to more targeted and effective business decisions. For instance, it might be beneficial to offer specific promotions or adjust pricing strategies based on the preferences and behaviors of customers with different educational backgrounds, marital statuses, or geographic locations.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import month, year, current_date, datediff, to_date, col

# Initialize Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Assuming you have a Spark DataFrame named sales_filtered
# Replace 'your_data.csv' with the actual data source
# sales_filtered = spark.read.csv('your_data.csv', header=True, inferSchema=True)

# Convert "birthdate" to date type
sales_filtered = sales_filtered.withColumn("birthdate", to_date("birthdate", "M/d/yyyy"))

# Extract birth month and birth year
sales_filtered = sales_filtered.withColumn("BirthMonth", month("birthdate"))
sales_filtered = sales_filtered.withColumn("BirthYear", year("birthdate"))

# Calculate age based on the assumption that the current year is 2014
sales_filtered = sales_filtered.withColumn("Age", 
    (datediff(current_date(), "birthdate") / 365).cast("int")
)

# Show the resulting DataFrame
sales_filtered.show()
# Out:
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+-------------+----------+---------+---+
# |CustomerKey|CommuteDistance|   EnglishEducation|marital statust|EnglishProductSubcategoryName|  EnglishProductName|OrderDateKey|DueDateKey|ShipDateKey|Sales Terirory|       Country|         CITY|           Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income| birthdate|Gender| promo name|        CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderDate|DueDate|ShipDate|OrderMonth|OrderDayOfWeek|OrderDayMonth|BirthMonth|BirthYear|Age|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+-------------+----------+---------+---+
# |      21768|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|        Canada|    Metchosin|   British Columbia|              3|             1|                  0|             5|      70000.0|1946-08-22|     M|No Discount|     Canadian Dollar|               Canada|       1892000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             4|         12-4|         8|     1946| 77|
# |      28389|      0-1 Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|        France|       Pantin|  Seine Saint Denis|              0|             0|                  3|             3|      20000.0|1964-12-18|     F|No Discount|        French Franc|               France|       1002000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|         12-4|        12|     1964| 59|
# |      25863|      10+ Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest| United States|      Lebanon|             Oregon|              3|             1|                  0|             5|      40000.0|1946-12-03|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|         12-4|        12|     1946| 77|
# |      14501|      1-2 Miles|    Graduate Degree|              M|                   Road Bikes|  Road-650 Black, 62|  2010-12-29|2011-01-10| 2011-01-05|     Southwest| United States|Beverly Hills|         California|              2|             1|                  0|             4|      80000.0|1938-05-13|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|        12|             4|         12-4|         5|     1938| 85|
# |      11003|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Silv...|  2010-12-29|2011-01-10| 2011-01-05|     Southwest|     Australia|   North Ryde|    New South Wales|              1|             0|                  0|             0|      70000.0|1968-02-15|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             4|         12-4|         2|     1968| 55|
# |      27645|     5-10 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 44|  2010-12-30|2011-01-11| 2011-01-06|     Southwest| United States|     Coronado|         California|              4|             1|                  3|             1|     120000.0|1961-08-18|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             5|         12-5|         8|     1961| 62|
# |      16624|      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|        Perth|    South Australia|              3|             0|                  0|             0|      90000.0|1972-07-27|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             5|         12-5|         7|     1972| 51|
# |      11005|     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Blac...|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|East Brisbane|         Queensland|              1|             1|                  0|             0|      70000.0|1965-08-05|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3374.99|       3374.99|                 0.0|           0.0|            1898.09|         1898.09|    3374.99| 270.0|  84.37|  00:00.0|00:00.0| 00:00.0|        12|             5|         12-5|         8|     1965| 58|
# |      11011|      10+ Miles|          Bachelors|              M|               Mountain Bikes|Mountain-100 Silv...|  2010-12-30|2011-01-11| 2011-01-06|     Southwest|     Australia|East Brisbane|         Queensland|              4|             1|                  4|             4|      60000.0|1963-11-04|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|  00:00.0|00:00.0| 00:00.0|        12|             5|         12-5|        11|     1963| 60|
# |      27621|      1-2 Miles|    Graduate Degree|              S|                   Road Bikes|    Road-150 Red, 48|  2010-12-31|2011-01-12| 2011-01-07|     Southwest| United States| Santa Monica|         California|              4|             0|                  0|             0|     160000.0|1964-01-27|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|         12-6|         1|     1964| 59|
# |      27616|      2-5 Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 48|  2010-12-31|2011-01-12| 2011-01-07|     Southwest| United States|  Lemon Grove|         California|              4|             1|                  2|             3|     120000.0|1965-12-11|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|         12-6|        12|     1965| 58|
# |      20042|      1-2 Miles|          Bachelors|              M|                   Road Bikes|    Road-650 Red, 52|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|United Kingdom|    Liverpool|            England|              0|             1|                  1|             1|      40000.0|1974-05-04|     M|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|  00:00.0|00:00.0| 00:00.0|        12|             6|         12-6|         5|     1974| 49|
# |      16351|      1-2 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 52|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|     Australia|  Rockhampton|         Queensland|              2|             0|                  0|             2|      80000.0|1954-07-07|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|         12-6|         7|     1954| 69|
# |      16517|      2-5 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 56|  2010-12-31|2011-01-12| 2011-01-07|     Southwest|     Australia|   Wollongong|    New South Wales|              0|             1|                  1|             1|      10000.0|1976-03-19|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|        12|             6|         12-6|         3|     1976| 47|
# |      27606|      0-1 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 56|  2011-01-01|2011-01-13| 2011-01-08|     Southwest| United States|    Milwaukie|             Oregon|              0|             0|                  1|             2|      70000.0|1957-05-27|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             7|          1-7|         5|     1957| 66|
# |      13513|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-01|2011-01-13| 2011-01-08|     Southwest|       Germany|        Werne|Nordrhein-Westfalen|              0|             1|                  0|             1|      30000.0|1941-09-08|     F|No Discount|       Deutsche Mark|              Germany|        993000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             7|          1-7|         9|     1941| 82|
# |      27601|      2-5 Miles|Partial High School|              S|                   Road Bikes|    Road-150 Red, 62|  2011-01-02|2011-01-14| 2011-01-09|     Southwest| United States|      Burbank|         California|              3|             0|                  1|             3|      60000.0|1953-11-10|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|          1-1|        11|     1953| 70|
# |      13591|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|United Kingdom|         York|            England|              3|             1|                  5|             0|     170000.0|1953-05-25|     F|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|          1-1|         5|     1953| 70|
# |      16483|     5-10 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 56|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|     Australia|    Melbourne|           Victoria|              2|             1|                  0|             2|      40000.0|1950-10-17|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|          1-1|        10|     1950| 73|
# |      16529|      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|  2011-01-02|2011-01-14| 2011-01-09|     Southwest|     Australia|     Goulburn|    New South Wales|              0|             1|                  0|             0|      20000.0|1977-07-28|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|  00:00.0|00:00.0| 00:00.0|         1|             1|          1-1|         7|     1977| 46|
# +-----------+---------------+-------------------+---------------+-----------------------------+--------------------+------------+----------+-----------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+----------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+---------+-------+--------+----------+--------------+-------------+----------+---------+---+
# only showing top 20 rows

# %% [markdown]
# # Data analysis and modeling
# for theis analysi we drop teh key columns as theyre not factors to be conisdeered in he analysis. and also the dates column

# %%
spark = SparkSession.builder.appName("example").getOrCreate()


# List all columns to drop
columns_to_drop = [
    col for col in sales_filtered.columns 
    if any(keyword in col.lower() for keyword in ['key', 'orderdate', 'duedate', 'shipdate','birthdate','SalesOrderNumber','CarrierTrackingNumber','CustomerPONumber'])
]

# Drop the identified columns from the DataFrame
sales_filtered_filtered = sales_filtered.drop(*columns_to_drop)

# Show the resulting DataFrame
sales_filtered_filtered.show()
# Out:
# +---------------+-------------------+---------------+-----------------------------+--------------------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |CommuteDistance|   EnglishEducation|marital statust|EnglishProductSubcategoryName|  EnglishProductName|Sales Terirory|       Country|         CITY|           Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income|Gender| promo name|        CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderMonth|OrderDayOfWeek|OrderDayMonth|BirthMonth|BirthYear|Age|
# +---------------+-------------------+---------------+-----------------------------+--------------------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|     Southwest|        Canada|    Metchosin|   British Columbia|              3|             1|                  0|             5|      70000.0|     M|No Discount|     Canadian Dollar|               Canada|       1892000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             4|         12-4|         8|     1946| 77|
# |      0-1 Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|     Southwest|        France|       Pantin|  Seine Saint Denis|              0|             0|                  3|             3|      20000.0|     F|No Discount|        French Franc|               France|       1002000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|        12|             4|         12-4|        12|     1964| 59|
# |      10+ Miles|        High School|              S|               Mountain Bikes|Mountain-100 Silv...|     Southwest| United States|      Lebanon|             Oregon|              3|             1|                  0|             5|      40000.0|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|        12|             4|         12-4|        12|     1946| 77|
# |      1-2 Miles|    Graduate Degree|              M|                   Road Bikes|  Road-650 Black, 62|     Southwest| United States|Beverly Hills|         California|              2|             1|                  0|             4|      80000.0|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|        12|             4|         12-4|         5|     1938| 85|
# |     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Silv...|     Southwest|     Australia|   North Ryde|    New South Wales|              1|             0|                  0|             0|      70000.0|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|        12|             4|         12-4|         2|     1968| 55|
# |     5-10 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 44|     Southwest| United States|     Coronado|         California|              4|             1|                  3|             1|     120000.0|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             5|         12-5|         8|     1961| 62|
# |      10+ Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 62|     Southwest|     Australia|        Perth|    South Australia|              3|             0|                  0|             0|      90000.0|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             5|         12-5|         7|     1972| 51|
# |     5-10 Miles|          Bachelors|              S|               Mountain Bikes|Mountain-100 Blac...|     Southwest|     Australia|East Brisbane|         Queensland|              1|             1|                  0|             0|      70000.0|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3374.99|       3374.99|                 0.0|           0.0|            1898.09|         1898.09|    3374.99| 270.0|  84.37|        12|             5|         12-5|         8|     1965| 58|
# |      10+ Miles|          Bachelors|              M|               Mountain Bikes|Mountain-100 Silv...|     Southwest|     Australia|East Brisbane|         Queensland|              4|             1|                  4|             4|      60000.0|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3399.99|       3399.99|                 0.0|           0.0|            1912.15|         1912.15|    3399.99| 272.0|   85.0|        12|             5|         12-5|        11|     1963| 60|
# |      1-2 Miles|    Graduate Degree|              S|                   Road Bikes|    Road-150 Red, 48|     Southwest| United States| Santa Monica|         California|              4|             0|                  0|             0|     160000.0|     M|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             6|         12-6|         1|     1964| 59|
# |      2-5 Miles|          Bachelors|              S|                   Road Bikes|    Road-150 Red, 48|     Southwest| United States|  Lemon Grove|         California|              4|             1|                  2|             3|     120000.0|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             6|         12-6|        12|     1965| 58|
# |      1-2 Miles|          Bachelors|              M|                   Road Bikes|    Road-650 Red, 52|     Southwest|United Kingdom|    Liverpool|            England|              0|             1|                  1|             1|      40000.0|     M|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|    699.1|         699.1|                 0.0|           0.0|             413.15|          413.15|      699.1| 55.93|  17.48|        12|             6|         12-6|         5|     1974| 49|
# |      1-2 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 52|     Southwest|     Australia|  Rockhampton|         Queensland|              2|             0|                  0|             2|      80000.0|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             6|         12-6|         7|     1954| 69|
# |      2-5 Miles|        High School|              M|                   Road Bikes|    Road-150 Red, 56|     Southwest|     Australia|   Wollongong|    New South Wales|              0|             1|                  1|             1|      10000.0|     F|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|        12|             6|         12-6|         3|     1976| 47|
# |      0-1 Miles|    Partial College|              S|                   Road Bikes|    Road-150 Red, 56|     Southwest| United States|    Milwaukie|             Oregon|              0|             0|                  1|             2|      70000.0|     F|No Discount|           US Dollar|        United States|       2693000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             7|          1-7|         5|     1957| 66|
# |      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|     Southwest|       Germany|        Werne|Nordrhein-Westfalen|              0|             1|                  0|             1|      30000.0|     F|No Discount|       Deutsche Mark|              Germany|        993000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             7|          1-7|         9|     1941| 82|
# |      2-5 Miles|Partial High School|              S|                   Road Bikes|    Road-150 Red, 62|     Southwest| United States|      Burbank|         California|              3|             0|                  1|             3|      60000.0|     F|No Discount|           US Dollar|        United States|       2427000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             1|          1-1|        11|     1953| 70|
# |      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|     Southwest|United Kingdom|         York|            England|              3|             1|                  5|             0|     170000.0|     F|No Discount|United Kingdom Pound|       United Kingdom|       2212000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             1|          1-1|         5|     1953| 70|
# |     5-10 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 56|     Southwest|     Australia|    Melbourne|           Victoria|              2|             1|                  0|             2|      40000.0|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             1|          1-1|        10|     1950| 73|
# |      0-1 Miles|          Bachelors|              M|                   Road Bikes|    Road-150 Red, 44|     Southwest|     Australia|     Goulburn|    New South Wales|              0|             1|                  0|             0|      20000.0|     M|No Discount|   Australian Dollar|            Australia|        867000.0|            1|  3578.27|       3578.27|                 0.0|           0.0|            2171.29|         2171.29|    3578.27|286.26|  89.46|         1|             1|          1-1|         7|     1977| 46|
# +---------------+-------------------+---------------+-----------------------------+--------------------+--------------+--------------+-------------+-------------------+---------------+--------------+-------------------+--------------+-------------+------+-----------+--------------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# only showing top 20 rows

# %% [markdown]
# # CLASSIFICATION MODELS

# %% [markdown]
# ##  Logistics regression

# %%
import pyspark.sql.functions as F
from pyspark.sql.window import Window

# Assuming df is your PySpark DataFrame
categorical_columns = ['CommuteDistance', 'EnglishEducation', 'marital statust', 
                        'EnglishProductSubcategoryName', 'EnglishProductName', 'Sales Terirory',
                        'Country', 'CITY', 'Province', 'Gender', 'promo name', 
                        'CurrencyName', 'SalesTerritoryCountry']
df = sales_filtered_filtered
# Convert to integers based on unique values
for column in categorical_columns:
    df = df.withColumn(column, F.dense_rank().over(Window.orderBy(column)))

# Now your DataFrame should have the specified columns encoded as integers.
df.show()
# Out:
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |CommuteDistance|EnglishEducation|marital statust|EnglishProductSubcategoryName|EnglishProductName|Sales Terirory|Country|CITY|Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income|Gender|promo name|CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderMonth|OrderDayOfWeek|OrderDayMonth|BirthMonth|BirthYear|Age|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |              3|               1|              1|                            2|                 2|             1|      1|  77|      27|              4|             1|                  0|             0|      90000.0|     1|         1|           1|                    1|        867000.0|            1|    159.0|         159.0|                 0.0|           0.0|              59.47|           59.47|      159.0| 12.72|   3.98|         5|             6|          5-6|         2|     1971| 52|
# |              1|               1|              1|                            5|                 3|             1|      1|  77|      27|              2|             0|                  4|             4|      60000.0|     1|         1|           1|                    1|        867000.0|            1|     7.95|          7.95|                 0.0|           0.0|               2.97|            2.97|       7.95|  0.64|    0.2|         5|             3|          5-3|        10|     1964| 59|
# |              3|               1|              1|                            5|                 3|             1|      1|  77|      27|              4|             1|                  5|             5|      70000.0|     1|         1|           1|                    1|        867000.0|            1|     7.95|          7.95|                 0.0|           0.0|               2.97|            2.97|       7.95|  0.64|    0.2|         3|             6|          3-6|         9|     1967| 56|
# |              1|               2|              1|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|      80000.0|     1|         1|           1|                    1|        867000.0|            1|     7.95|          7.95|                 0.0|           0.0|               2.97|            2.97|       7.95|  0.64|    0.2|         4|             6|          4-6|         3|     1970| 53|
# |              1|               2|              2|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|      80000.0|     1|         1|           1|                    1|        867000.0|            1|     7.95|          7.95|                 0.0|           0.0|               2.97|            2.97|       7.95|  0.64|    0.2|         6|             4|          6-4|         2|     1970| 53|
# |              3|               1|              1|                           17|                 4|             1|      1|  77|      27|              3|             0|                  0|             0|      80000.0|     1|         1|           1|                    1|        867000.0|            1|     63.5|          63.5|                 0.0|           0.0|              23.75|           23.75|       63.5|  5.08|   1.59|        12|             1|         12-1|         2|     1972| 51|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|      60000.0|     1|         1|           1|                    1|        867000.0|            1|    21.98|         21.98|                 0.0|           0.0|               8.22|            8.22|      21.98|  1.76|   0.55|         5|             4|          5-4|         3|     1964| 59|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|      60000.0|     1|         1|           1|                    1|        867000.0|            1|    21.98|         21.98|                 0.0|           0.0|               8.22|            8.22|      21.98|  1.76|   0.55|        12|             4|         12-4|         4|     1964| 59|
# |              1|               4|              1|                            6|                 7|             1|      1|  77|      27|              1|             1|                  0|             1|      60000.0|     1|         1|           1|                    1|        867000.0|            1|    21.98|         21.98|                 0.0|           0.0|               8.22|            8.22|      21.98|  1.76|   0.55|         8|             4|          8-4|         4|     1960| 63|
# |              3|               1|              2|                            6|                 7|             1|      1|  77|      27|              4|             0|                  0|             0|      90000.0|     1|         1|           1|                    1|        867000.0|            1|    21.98|         21.98|                 0.0|           0.0|               8.22|            8.22|      21.98|  1.76|   0.55|        10|             6|         10-6|        12|     1970| 53|
# |              5|               3|              1|                            7|                10|             1|      1|  77|      27|              2|             1|                  0|             3|      30000.0|     1|         1|           1|                    1|        867000.0|            1|    24.49|         24.49|                 0.0|           0.0|               9.16|            9.16|      24.49|  1.96|   0.61|         7|             5|          7-5|        12|     1952| 71|
# |              1|               1|              2|                            7|                11|             1|      1|  77|      27|              1|             0|                  0|             0|      70000.0|     1|         1|           1|                    1|        867000.0|            1|    24.49|         24.49|                 0.0|           0.0|               9.16|            9.16|      24.49|  1.96|   0.61|         2|             7|          2-7|        11|     1963| 60|
# |              5|               1|              1|                            7|                12|             1|      1|  77|      27|              1|             1|                  0|             1|      90000.0|     1|         1|           1|                    1|        867000.0|            1|    24.49|         24.49|                 0.0|           0.0|               9.16|            9.16|      24.49|  1.96|   0.61|         8|             6|          8-6|         6|     1959| 64|
# |              3|               1|              2|                            7|                12|             1|      1|  77|      27|              4|             0|                  0|             0|      90000.0|     1|         1|           1|                    1|        867000.0|            1|    24.49|         24.49|                 0.0|           0.0|               9.16|            9.16|      24.49|  1.96|   0.61|         7|             5|          7-5|        12|     1970| 53|
# |              5|               1|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  3|             3|      60000.0|     1|         1|           1|                    1|        867000.0|            1|    54.99|         54.99|                 0.0|           0.0|              20.57|           20.57|      54.99|   4.4|   1.37|         5|             4|          5-4|         3|     1964| 59|
# |              5|               5|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  1|             2|      20000.0|     1|         1|           1|                    1|        867000.0|            1|    54.99|         54.99|                 0.0|           0.0|              20.57|           20.57|      54.99|   4.4|   1.37|        10|             5|         10-5|         5|     1950| 73|
# |              1|               4|              2|                            9|                14|             1|      1|  77|      27|              1|             0|                  0|             0|      10000.0|     1|         1|           1|                    1|        867000.0|            1|    54.99|         54.99|                 0.0|           0.0|              20.57|           20.57|      54.99|   4.4|   1.37|        11|             5|         11-5|        11|     1978| 45|
# |              5|               1|              1|                            3|                23|             1|      1|  77|      27|              2|             1|                  3|             3|      60000.0|     1|         1|           1|                    1|        867000.0|            1|     9.99|          9.99|                 0.0|           0.0|               3.74|            3.74|       9.99|   0.8|   0.25|         5|             4|          5-4|         3|     1964| 59|
# |              1|               2|              1|                            3|                23|             1|      1|  77|      27|              1|             1|                  4|             4|      80000.0|     1|         1|           1|                    1|        867000.0|            1|     9.99|          9.99|                 0.0|           0.0|               3.74|            3.74|       9.99|   0.8|   0.25|         7|             6|          7-6|         3|     1970| 53|
# |              3|               1|              2|                            3|                23|             1|      1|  77|      27|              4|             0|                  0|             0|      90000.0|     1|         1|           1|                    1|        867000.0|            1|     9.99|          9.99|                 0.0|           0.0|               3.74|            3.74|       9.99|   0.8|   0.25|        10|             6|         10-6|        12|     1970| 53|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col


for column_name in df.columns:
    df = df.withColumn(column_name, col(column_name).cast('int'))

# Show the updated DataFrame
df.show()
# Out:
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |CommuteDistance|EnglishEducation|marital statust|EnglishProductSubcategoryName|EnglishProductName|Sales Terirory|Country|CITY|Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income|Gender|promo name|CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderMonth|OrderDayOfWeek|OrderDayMonth|BirthMonth|BirthYear|Age|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# |              3|               1|              1|                            2|                 2|             1|      1|  77|      27|              4|             1|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|      159|           159|                   0|             0|                 59|              59|        159|    12|      3|         5|             6|         NULL|         2|     1971| 52|
# |              1|               1|              1|                            5|                 3|             1|      1|  77|      27|              2|             0|                  4|             4|        60000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         5|             3|         NULL|        10|     1964| 59|
# |              3|               1|              1|                            5|                 3|             1|      1|  77|      27|              4|             1|                  5|             5|        70000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         3|             6|         NULL|         9|     1967| 56|
# |              1|               2|              1|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         4|             6|         NULL|         3|     1970| 53|
# |              1|               2|              2|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         6|             4|         NULL|         2|     1970| 53|
# |              3|               1|              1|                           17|                 4|             1|      1|  77|      27|              3|             0|                  0|             0|        80000|     1|         1|           1|                    1|          867000|            1|       63|            63|                   0|             0|                 23|              23|         63|     5|      1|        12|             1|         NULL|         2|     1972| 51|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|         5|             4|         NULL|         3|     1964| 59|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|        12|             4|         NULL|         4|     1964| 59|
# |              1|               4|              1|                            6|                 7|             1|      1|  77|      27|              1|             1|                  0|             1|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|         8|             4|         NULL|         4|     1960| 63|
# |              3|               1|              2|                            6|                 7|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|        10|             6|         NULL|        12|     1970| 53|
# |              5|               3|              1|                            7|                10|             1|      1|  77|      27|              2|             1|                  0|             3|        30000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         7|             5|         NULL|        12|     1952| 71|
# |              1|               1|              2|                            7|                11|             1|      1|  77|      27|              1|             0|                  0|             0|        70000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         2|             7|         NULL|        11|     1963| 60|
# |              5|               1|              1|                            7|                12|             1|      1|  77|      27|              1|             1|                  0|             1|        90000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         8|             6|         NULL|         6|     1959| 64|
# |              3|               1|              2|                            7|                12|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         7|             5|         NULL|        12|     1970| 53|
# |              5|               1|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|         5|             4|         NULL|         3|     1964| 59|
# |              5|               5|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  1|             2|        20000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|        10|             5|         NULL|         5|     1950| 73|
# |              1|               4|              2|                            9|                14|             1|      1|  77|      27|              1|             0|                  0|             0|        10000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|        11|             5|         NULL|        11|     1978| 45|
# |              5|               1|              1|                            3|                23|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|         5|             4|         NULL|         3|     1964| 59|
# |              1|               2|              1|                            3|                23|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|         7|             6|         NULL|         3|     1970| 53|
# |              3|               1|              2|                            3|                23|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|        10|             6|         NULL|        12|     1970| 53|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+-------------+----------+---------+---+
# only showing top 20 rows

# %%
# Assuming your DataFrame is named df
data_types = df.dtypes

# Display the data types
print(data_types)2
# Out:
# [('CommuteDistance', 'int'), ('EnglishEducation', 'int'), ('marital statust', 'int'), ('EnglishProductSubcategoryName', 'int'), ('EnglishProductName', 'int'), ('Sales Terirory', 'int'), ('Country', 'int'), ('CITY', 'int'), ('Province', 'int'), ('NumberCarsOwned', 'int'), ('HouseOwnerFlag', 'int'), ('number  fo children', 'int'), ('total children', 'int'), ('annual income', 'int'), ('Gender', 'int'), ('promo name', 'int'), ('CurrencyName', 'int'), ('SalesTerritoryCountry', 'int'), ('SalesAmountQuote', 'int'), ('OrderQuantity', 'int'), ('UnitPrice', 'int'), ('ExtendedAmount', 'int'), ('UnitPriceDiscountPct', 'int'), ('DiscountAmount', 'int'), ('ProductStandardCost', 'int'), ('TotalProductCost', 'int'), ('SalesAmount', 'int'), ('TaxAmt', 'int'), ('Freight', 'int'), ('OrderMonth', 'int'), ('OrderDayOfWeek', 'int'), ('OrderDayMonth', 'int'), ('BirthMonth', 'int'), ('BirthYear', 'int'), ('Age', 'int')]

# %%
from pyspark.sql import SparkSession
import pandas as pd

# Create Spark session
spark = SparkSession.builder.appName("example").getOrCreate()

# Load Excel file into pandas DataFrame
file_path = "output.xlsx"
df_pandas = pd.read_excel(file_path)

# Convert pandas DataFrame to Spark DataFrame
df_spark = spark.createDataFrame(df_pandas)

# Show the Spark DataFrame
try:
    df_spark.show()
except Exception as e:
    print(e)
# Out:
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+----------+---------+---+
# |CommuteDistance|EnglishEducation|marital statust|EnglishProductSubcategoryName|EnglishProductName|Sales Terirory|Country|CITY|Province|NumberCarsOwned|HouseOwnerFlag|number  fo children|total children|annual income|Gender|promo name|CurrencyName|SalesTerritoryCountry|SalesAmountQuote|OrderQuantity|UnitPrice|ExtendedAmount|UnitPriceDiscountPct|DiscountAmount|ProductStandardCost|TotalProductCost|SalesAmount|TaxAmt|Freight|OrderMonth|OrderDayOfWeek|BirthMonth|BirthYear|Age|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+----------+---------+---+
# |              3|               1|              1|                            2|                 2|             1|      1|  77|      27|              4|             1|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|      159|           159|                   0|             0|                 59|              59|        159|    12|      3|         5|             6|         2|     1971| 52|
# |              1|               1|              1|                            5|                 3|             1|      1|  77|      27|              2|             0|                  4|             4|        60000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         5|             3|        10|     1964| 59|
# |              3|               1|              1|                            5|                 3|             1|      1|  77|      27|              4|             1|                  5|             5|        70000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         3|             6|         9|     1967| 56|
# |              1|               2|              1|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         4|             6|         3|     1970| 53|
# |              1|               2|              2|                            5|                 3|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        7|             7|                   0|             0|                  2|               2|          7|     0|      0|         6|             4|         2|     1970| 53|
# |              3|               1|              1|                           17|                 4|             1|      1|  77|      27|              3|             0|                  0|             0|        80000|     1|         1|           1|                    1|          867000|            1|       63|            63|                   0|             0|                 23|              23|         63|     5|      1|        12|             1|         2|     1972| 51|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|         5|             4|         3|     1964| 59|
# |              5|               1|              1|                            6|                 7|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|        12|             4|         4|     1964| 59|
# |              1|               4|              1|                            6|                 7|             1|      1|  77|      27|              1|             1|                  0|             1|        60000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|         8|             4|         4|     1960| 63|
# |              3|               1|              2|                            6|                 7|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|       21|            21|                   0|             0|                  8|               8|         21|     1|      0|        10|             6|        12|     1970| 53|
# |              5|               3|              1|                            7|                10|             1|      1|  77|      27|              2|             1|                  0|             3|        30000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         7|             5|        12|     1952| 71|
# |              1|               1|              2|                            7|                11|             1|      1|  77|      27|              1|             0|                  0|             0|        70000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         2|             7|        11|     1963| 60|
# |              5|               1|              1|                            7|                12|             1|      1|  77|      27|              1|             1|                  0|             1|        90000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         8|             6|         6|     1959| 64|
# |              3|               1|              2|                            7|                12|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|       24|            24|                   0|             0|                  9|               9|         24|     1|      0|         7|             5|        12|     1970| 53|
# |              5|               1|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|         5|             4|         3|     1964| 59|
# |              5|               5|              1|                            9|                14|             1|      1|  77|      27|              2|             1|                  1|             2|        20000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|        10|             5|         5|     1950| 73|
# |              1|               4|              2|                            9|                14|             1|      1|  77|      27|              1|             0|                  0|             0|        10000|     1|         1|           1|                    1|          867000|            1|       54|            54|                   0|             0|                 20|              20|         54|     4|      1|        11|             5|        11|     1978| 45|
# |              5|               1|              1|                            3|                23|             1|      1|  77|      27|              2|             1|                  3|             3|        60000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|         5|             4|         3|     1964| 59|
# |              1|               2|              1|                            3|                23|             1|      1|  77|      27|              1|             1|                  4|             4|        80000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|         7|             6|         3|     1970| 53|
# |              3|               1|              2|                            3|                23|             1|      1|  77|      27|              4|             0|                  0|             0|        90000|     1|         1|           1|                    1|          867000|            1|        9|             9|                   0|             0|                  3|               3|          9|     0|      0|        10|             6|        12|     1970| 53|
# +---------------+----------------+---------------+-----------------------------+------------------+--------------+-------+----+--------+---------------+--------------+-------------------+--------------+-------------+------+----------+------------+---------------------+----------------+-------------+---------+--------------+--------------------+--------------+-------------------+----------------+-----------+------+-------+----------+--------------+----------+---------+---+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline
from pyspark.sql.functions import col


# Target variable
target_variable = 'Gender'

# Get all columns except the target variable
feature_columns = [col for col in df_spark.columns if col != target_variable]

# Assemble the features into a vector
vector_assembler = VectorAssembler(inputCols=feature_columns, outputCol='features')

# Initialize Logistic Regression model
logistic_regression = LogisticRegression(featuresCol='features', labelCol=target_variable)

# Create a pipeline with the vector assembler and logistic regression model
pipeline = Pipeline(stages=[vector_assembler, logistic_regression])

# Fit the pipeline to the DataFrame
model = pipeline.fit(df_spark)

# Make predictions on the DataFrame
predictions = model.transform(df_spark)

# Show the predictions
predictions.select(target_variable, 'features', 'rawPrediction', 'probability', 'prediction').show()
# Out:
# +------+--------------------+--------------------+--------------------+----------+
# |Gender|            features|       rawPrediction|         probability|prediction|
# +------+--------------------+--------------------+--------------------+----------+
# |     1|[3.0,1.0,1.0,2.0,...|[-7.5843703131400...|[5.71582235647021...|       2.0|
# |     1|[1.0,1.0,1.0,5.0,...|[-7.5836952292498...|[5.71698318587438...|       2.0|
# |     1|[3.0,1.0,1.0,5.0,...|[-7.5835608890911...|[5.73424159439698...|       2.0|
# |     1|[1.0,2.0,1.0,5.0,...|[-7.5839563427372...|[5.72853213704676...|       2.0|
# |     1|[1.0,2.0,2.0,5.0,...|[-7.5838173222489...|[5.71817252394913...|       1.0|
# |     1|[3.0,1.0,1.0,17.0...|[-7.5841194190073...|[5.66831335954813...|       2.0|
# |     1|[5.0,1.0,1.0,6.0,...|[-7.5837877805035...|[5.72309196774663...|       2.0|
# |     1|[5.0,1.0,1.0,6.0,...|[-7.5837968542148...|[5.72236549509820...|       2.0|
# |     1|[1.0,4.0,1.0,6.0,...|[-7.5842263149285...|[5.72730285261626...|       2.0|
# |     1|[3.0,1.0,2.0,6.0,...|[-7.5841851532129...|[5.72777894089685...|       1.0|
# |     1|[5.0,3.0,1.0,7.0,...|[-7.5838142657515...|[5.73508133832134...|       2.0|
# |     1|[1.0,1.0,2.0,7.0,...|[-7.5844757134223...|[5.71741513173680...|       1.0|
# |     1|[5.0,1.0,1.0,7.0,...|[-7.5843831388287...|[5.72794945997989...|       2.0|
# |     1|[3.0,1.0,2.0,7.0,...|[-7.5842016484557...|[5.72652835993970...|       1.0|
# |     1|[5.0,1.0,1.0,9.0,...|[-7.5837885409060...|[5.72340509436850...|       2.0|
# |     1|[5.0,5.0,1.0,9.0,...|[-7.5833870462023...|[5.72663343317233...|       2.0|
# |     1|[1.0,4.0,2.0,9.0,...|[-7.5842870328145...|[5.72797590721868...|       1.0|
# |     1|[5.0,1.0,1.0,3.0,...|[-7.5837970948392...|[5.72358675121744...|       2.0|
# |     1|[1.0,2.0,1.0,3.0,...|[-7.5839573360580...|[5.72770564485111...|       2.0|
# |     1|[3.0,1.0,2.0,3.0,...|[-7.5841944675486...|[5.72734897508827...|       1.0|
# +------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows
